# %% [markdown]
# # **Problem Statement:**
#
# The objective of this regression project is to analyze the Medical Cost Dataset, which contains comprehensive information about medical costs and healthcare expenses. The primary goal is to develop a predictive model that can accurately estimate medical charges based on various factors and attributes present in the dataset. By doing so, we aim to address the following key questions and challenges within the healthcare industry:
#
# 1. Cost Estimation:
#    - How can we effectively estimate medical charges for patients based on their unique characteristics, such as age, gender, BMI, smoking status, region, and other relevant attributes?
#
# 2. Factors Influencing Costs:
#    - What are the primary factors and variables that significantly influence medical expenses? Which factors have the most substantial impact on healthcare costs?
#
# 3. Regional Disparities:
#    - Are there regional disparities in medical costs? Do certain geographic areas exhibit higher or lower healthcare expenses, and if so, what are the contributing factors?
#
# 4. Insurance Coverage:
#    - How does the presence or absence of health insurance coverage affect medical charges? Can we identify patterns in cost variations related to insurance status?
#
# 5. Lifestyle Choices:
#    - To what extent do lifestyle choices, such as smoking habits and BMI, impact medical costs? Can we quantify the additional expenses associated with specific lifestyle factors?
#
# 6. Pre-existing Conditions:
#    - Are individuals with pre-existing medical conditions more likely to incur higher healthcare expenses? Can we predict the added costs associated with particular health conditions?
#
# 7. Model Accuracy:
#    - What is the accuracy of the developed regression model in predicting medical charges? How well does it perform in comparison to existing methods or benchmarks?
#
# By addressing these questions, we aim to provide valuable insights for healthcare professionals, policymakers, and analysts to make informed decisions regarding resource allocation, healthcare planning, and cost containment strategies. Additionally, this project seeks to enhance our understanding of the intricate dynamics within the healthcare industry and contribute to more equitable and cost-effective healthcare solutions.

# %% [markdown]
# Data Link: https://www.kaggle.com/datasets/nanditapore/medical-cost-dataset?resource=download

# %% [markdown]
# ## **Data Collection:**

# %%
# Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, RidgeCV
from sklearn.linear_model import Lasso, LassoCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")

plt.rcParams['figure.figsize'] = [15,9]
sns.set(rc={'figure.figsize':(15,9)})

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Loading the dataset
medical_df = pd.read_csv('/content/drive/My Drive/Medical Charges Prediction/medical_cost.csv')

# Display the top 5 rows
medical_df.head()
# Out:
#    Id  age     sex     bmi  children smoker     region      charges
# 0   1   19  female  27.900         0    yes  southwest  16884.92400
# 1   2   18    male  33.770         1     no  southeast   1725.55230
# 2   3   28    male  33.000         3     no  southeast   4449.46200
# 3   4   33    male  22.705         0     no  northwest  21984.47061
# 4   5   32    male  28.880         0     no  northwest   3866.85520

# %%
# Display the last 5 rows
medical_df.tail()
# Out:
#         Id  age     sex    bmi  children smoker     region     charges
# 1333  1334   50    male  30.97         3     no  northwest  10600.5483
# 1334  1335   18  female  31.92         0     no  northeast   2205.9808
# 1335  1336   18  female  36.85         0     no  southeast   1629.8335
# 1336  1337   21  female  25.80         0     no  southwest   2007.9450
# 1337  1338   61  female  29.07         0    yes  northwest  29141.3603

# %%
# Number of records in the data
len(medical_df)
# Out:
# 1338

# %%
# Shape of the dataset
medical_df.shape
# Out:
# (1338, 8)

# %%
# Columns in the dataset
medical_df.columns
# Out:
# Index(['Id', 'age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# Check the datatypes
medical_df.dtypes
# Out:
# Id            int64
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# * There are 1338 observations in the dataset with 8 columns present which is a fairly small and simple dataset.
# * Most of the columns contain numeric values apart from few which we might need to encode.
# * Our goal is to predict the charges which is our target variable here.

# %% [markdown]
# ### **Data Summary:**
#
# **Categorical Features:**
#
# - Sex: Determines the gender of the patient(Female/Male).
# - Smoker: Whether the patient smokes or not(Yes/No).
# - Region: From where the patient belongs.
#
# **Numerical Features:**
#
# - Id: Unique ID given for each observation.
# - Age: Determines the age of the patient.
# - BMI: Determines the body mass index of the patient.
# - Children: Whether the patient has any children or not,if yes how many.
# - Charges: Cost required for treatment which is our target variable to predict.

# %% [markdown]
# ### **Information/Description of the Dataset:**

# %%
# Summary statistics of the dataset
medical_df.describe()
# Out:
#                 Id          age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000  1338.000000   1338.000000
# mean    669.500000    39.207025    30.663397     1.094918  13270.422265
# std     386.391641    14.049960     6.098187     1.205493  12110.011237
# min       1.000000    18.000000    15.960000     0.000000   1121.873900
# 25%     335.250000    27.000000    26.296250     0.000000   4740.287150
# 50%     669.500000    39.000000    30.400000     1.000000   9382.033000
# 75%    1003.750000    51.000000    34.693750     2.000000  16639.912515
# max    1338.000000    64.000000    53.130000     5.000000  63770.428010

# %%
# Check for null values in the dataset
medical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        1338 non-null   int64
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
#  6   region    1338 non-null   object
#  7   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.8+ KB

# %%
# Check for missing values
medical_df.isnull().sum()
# Out:
# Id          0
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# * As the data is a very simple one we do not have any missing or null values so no need of handling or imputing them.

# %% [markdown]
# ## **Exploratory Data Analysis:**
#
# Exploratory Data Analysis or EDA is used to take insights from the data. Data Scientists and Analysts try to find different patterns, relations, and anomalies in the data using some statistical graphs and other visualization techniques.
#
# The main purpose of EDA is to detect any errors, outliers as well as to understand different patterns in the data. It allows Analysts to understand the data better before making any assumptions.
#
# We will be doing some univariate, bivariate and multivariate analysis to discover some insights from the data like:
#
#   * Distribution of age, children, bmi, charges.
#   * Distribution of gender, smoker, region.
#   * How charges are related to the other variables in the dataset etc.

# %% [markdown]
# ### **Distribution of Charges:**

# %%
# Distribution of charges
sns.histplot(medical_df['charges'])
plt.title("Medical Charges Distribution")
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * We can infer from the plot that most of the patients have been charged under 10k but there are very few patients for whom the charges have gone upto 60k.
# * The distribution is very much skewed to the right.

# %% [markdown]
# ### **Outlier detection in Charges:**

# %%
# Boxplots for outlier detection
sns.boxplot(medical_df['charges'])
plt.show()

# %% [markdown]
# * We can infer from the plot that anything above 35k is an outlier for this data.
# * But we cannot remove or drop these values as in healthcare data there will be a very few observations with higher amount of charges which might be due to some rare disease or so and these numbers will be always very less in any kind of dataset. Thus we cannot treat them as outliers just by inference from a boxplot.

# %% [markdown]
# ### **Distribution of Age:**

# %%
# Distribution of age
sns.histplot(medical_df['age'])
plt.title("Age Distribution")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * Surprisingly, most of the observants or patients in our dataset are young around the age of 20.
# * Follows an uniform distribution for the ages above 25 or so till 60.

# %% [markdown]
# ### **Distribution of BMI:**

# %%
# Distribution of bmi
sns.histplot(medical_df['bmi'])
plt.title("Body Mass Index Distribution")
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * The distribution of BMI follows a normal distribution where most of the data lies around 25 to 35 BMI.

# %% [markdown]
# ### **Distribution of Sex:**

# %%
# Distribution of gender
sns.histplot(medical_df['sex'])
plt.title("Gender Distribution")
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * We can infer from the plot that there is almost an equal distribution of male and female patients in our dataset.

# %% [markdown]
# ### **Distribution of Children:**

# %%
# Distribution of children
sns.histplot(medical_df['children'])
plt.title("Children Distribution")
plt.xlabel('Children')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * Most of the patients have no children or 1 child and there are very few who have 4-5 children.

# %% [markdown]
# ### **Distribution of Smoking:**

# %%
# Distribution of smoker
sns.histplot(medical_df['smoker'])
plt.title("Smoker Distribution")
plt.xlabel('Smoker')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * Most of the patients in our dataset are non smokers.

# %% [markdown]
# ### **Distribution of Regions:**

# %%
# Distribution of region
sns.histplot(medical_df['region'])
plt.title("Region Distribution")
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# * The regions are almost equally distributed in the dataset where only southeast has a couple more observations than other regions.

# %% [markdown]
# ### **How charges vary with the numerical features in the dataset:**

# %%
# Variation of charges with all numerical features
num_features = ['age', 'bmi', 'children']
count = 1
plt.subplots(figsize=(20,35))
for feature in num_features:
  plt.subplot(3,1,count)
  sns.scatterplot(data=medical_df, x=feature, y='charges')
  plt.title(f"How charge is related to the variable {feature}", fontsize=16)
  plt.xlabel(f"{feature}")
  plt.ylabel("Charges")
  count += 1

# %% [markdown]
# ### **How charges vary with the categorical features in the dataset:**

# %%
# Variation of charges with all categorical features
cat_features = ['sex', 'smoker', 'region']
count = 1
plt.subplots(figsize=(20,35))
for feature in cat_features:
  plt.subplot(3,1,count)
  sns.barplot(data=medical_df, x=feature, y='charges')
  plt.title(f"How charge is related to the variable {feature}", fontsize=16)
  plt.xlabel(f"{feature}")
  plt.ylabel("Charges")
  count += 1

# %% [markdown]
# ### **How charges vary with smoking in different genders:**

# %%
# Charges with smoking in different genders
sns.barplot(data=medical_df, x='sex', y='charges', hue='smoker')
plt.title("Charges against smoking in different genders")
plt.xlabel("Sex")
plt.ylabel("Charges")
plt.show()

# %% [markdown]
# ## **Feature Selection & Engineering:**

# %%
# Print the columns in the dataset
medical_df.columns
# Out:
# Index(['Id', 'age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %% [markdown]
# * We need to drop Id as it is just an unique identifier which won't help in our prediction purpose.
# * There are few categorical variables like sex, smoker, region which needs to be encoded into numerical variables.

# %%
# Drop the id column
medical_df.drop(['Id'], axis=1, inplace=True)

# %%
# One-hot encoding for region
medical_df = pd.get_dummies(medical_df, columns=['region'])
medical_df.head()
# Out:
#    age     sex     bmi  children smoker      charges  region_northeast  \
# 0   19  female  27.900         0    yes  16884.92400                 0
# 1   18    male  33.770         1     no   1725.55230                 0
# 2   28    male  33.000         3     no   4449.46200                 0
# 3   33    male  22.705         0     no  21984.47061                 0
# 4   32    male  28.880         0     no   3866.85520                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %%
# Encode the variables sex and smoker
medical_df['sex'] = medical_df['sex'].map({'male': 0, 'female': 1})
medical_df['smoker'] = medical_df['smoker'].map({'yes':1, 'no': 0})
medical_df.head()
# Out:
#    age  sex     bmi  children  smoker      charges  region_northeast  \
# 0   19    1  27.900         0       1  16884.92400                 0
# 1   18    0  33.770         1       0   1725.55230                 0
# 2   28    0  33.000         3       0   4449.46200                 0
# 3   33    0  22.705         0       0  21984.47061                 0
# 4   32    0  28.880         0       0   3866.85520                 0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %% [markdown]
# ### **Correlation Heatmap:**

# %%
# Calculate the correlation for the independent variables
independent_features = ['age','sex','bmi','children','smoker','region_northeast','region_northwest','region_southeast','region_southwest']

subset_df = medical_df[independent_features]

# Create a heatmap
sns.heatmap(subset_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation heatmap of selected features")
plt.show()

# %% [markdown]
# ### **How charges is correlated to the independent variables:**

# %%
# relation of independent variables with the dependent variable
count = 1
plt.subplots(figsize=(30,30))
for feature in independent_features:
  plt.subplot(5,2,count)
  var = medical_df[feature]
  label = medical_df['charges']
  correlation = var.corr(label)
  plt.scatter(x = var, y = label)
  plt.xlabel(feature)
  plt.ylabel('Charges')
  plt.title(f"Charges vs {feature} correlation: {correlation}")
  z = np.polyfit(var, label, 1)
  y_hat = np.poly1d(z)(medical_df[feature])
  plt.plot(medical_df[feature], y_hat, "r--", lw=2)
  count += 1

# %% [markdown]
# ### **Checking for Multicollinearity:**

# %%
# Multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(medical_df[[i for i in medical_df.describe().columns]])
# Out:
#           variables        VIF
# 0               age   1.373348
# 1               sex   1.009018
# 2               bmi   1.223757
# 3          children   1.013005
# 4            smoker   3.549468
# 5           charges   4.014662
# 6  region_northeast   9.776808
# 7  region_northwest   9.882767
# 8  region_southeast  13.059107
# 9  region_southwest  10.566261

# %% [markdown]
# ## **Model Selection & Training:**

# %% [markdown]
# ### **Data Preparation**

# %%
# Prepare the independent and dependent features
#independent_features = ['age','sex_female','sex_male','bmi','children','smoker_yes','smoker_no','region_northeast','region_northwest','region_southeast','region_southwest']
X = medical_df[independent_features]
Y = medical_df['charges']

# Print the shape of X and Y
print("The shape of X is", X.shape)
print("The shape of Y is", Y.shape)
# Out:
# The shape of X is (1338, 9)
# The shape of Y is (1338,)

# %% [markdown]
# #### **Evaluation Metrics for Regression:**

# %%
# func to evaluate metrics
from numpy import math
def print_metrics(actual, predicted):
  MSE = mean_squared_error(actual, predicted)
  RMSE = math.sqrt(mean_squared_error(actual, predicted))
  MAE = mean_absolute_error(actual, predicted)
  R2 = r2_score(actual, predicted)
  Adj_R2 = 1 - (((len(actual) - 1)/(len(actual) - len(independent_features) - 1)) * (1 - r2_score(actual, predicted)))

  print('MSE is {}'.format(MSE))
  print('RMSE is {}'.format(RMSE))
  print('MAE is {}'.format(mean_absolute_error(actual, predicted)))
  print('R2 score is {}'.format(R2))
  print('Adjusted R2 score is {}'.format(Adj_R2))

  return MSE, RMSE, MAE, R2, Adj_R2

# %% [markdown]
# #### **Function for plotting actual vs predicted values**

# %%
# function for visualizing actual vs predicted values
def visualize_difference(actual, predicted):
  plt.plot(np.array(actual), label='Actual')
  plt.plot(predicted, label='Predicted')
  plt.title("Actual vs Predicted Values")
  plt.xlabel("Test Data")
  plt.ylabel("Price")
  plt.legend()
  plt.show()

# %% [markdown]
# ### **Building a Linear Regression Model**

# %%
def linear_reg(X,Y):

  # split the data into train and test set
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
  print("The shape of training set is", X_train.shape, Y_train.shape)
  print("The shape of testing set is", X_test.shape, Y_test.shape)
  print("\n")

  # transforming the data
  scaler = MinMaxScaler()
  X_train = scaler.fit_transform(X_train)
  X_test = scaler.transform(X_test)

  # build a linear regression model
  lin_reg = LinearRegression()
  lin_reg.fit(X_train, Y_train)

  print(lin_reg.score(X_train, Y_train))
  print("\n")
  print("The coefficients are: ", lin_reg.coef_)
  print("The intercept is :", lin_reg.intercept_)
  print("---------------------------------------------------")
  print("\n")

  # predictions after modeling
  Y_train_pred = lin_reg.predict(X_train)
  Y_test_pred = lin_reg.predict(X_test)

  # Evaluating the linear regression model
  print("Train Set Metrics:")
  print("----------------------------------------------")
  print_metrics(Y_train, Y_train_pred)
  print("\n")

  print("Test Set Metrics")
  print("----------------------------------------------")
  metrics = print_metrics(Y_test, Y_test_pred)
  print("\n")
  r2_lr = metrics[3]

  # prediction in a dataframe
  pred = pd.DataFrame({'Actual Value': Y_test,
                       'Predicted Value': Y_test_pred})
  print("The top 5 rows of actual vs predicted values\n", pred.head())
  print("\n")

  # visualize actual vs predicted for linear regression
  visualize_difference(Y_test, Y_test_pred)

  return Y_test, Y_test_pred, r2_lr

# %%
# Run the model
lr = linear_reg(X,Y)
# Out:
# The shape of training set is (896, 9) (896,)
# The shape of testing set is (442, 9) (442,)
#
#
# 0.7553417867017556
#
#
# The coefficients are:  [11832.72546761   232.45032824 11719.45947263  1796.03189074
#  24128.57845945   534.33988268   202.35328171  -394.16275396
#   -342.53041043]
# The intercept is : -2170.295984780916
# ---------------------------------------------------
#
#
# Train Set Metrics:
# ----------------------------------------------
# MSE is 37048036.52133715
# RMSE is 6086.709827266053
# MAE is 4171.592044184442
# R2 score is 0.7553417867017556
# Adjusted R2 score is 0.7528565452574167
#
#
# Test Set Metrics
# ----------------------------------------------
# MSE is 35585029.808486596
# RMSE is 5965.318919260444
# MAE is 4080.1855242509696
# R2 score is 0.7394054641456174
# Adjusted R2 score is 0.7339764113153178
#
#
# The top 5 rows of actual vs predicted values
#        Actual Value  Predicted Value
# 559      1646.4297      4459.584295
# 1087    11353.2276     12976.423391
# 1020     8798.5930     12609.643246
# 460     10381.4787     13236.955445
# 802      2103.0800       617.040273

# %%
# Save the r2 score
r2_lr = lr[2]
print(r2_lr)
# Out:
# 0.7394054641456174

# %% [markdown]
# ### **Building a Decision Tree Regression Model**

# %%
def decision_tree(X,Y):

  # split the data into train and test set
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
  print("The shape of training set is", X_train.shape, Y_train.shape)
  print("The shape of testing set is", X_test.shape, Y_test.shape)
  print("\n")

  # hyperparameters
  param_dict = {'max_depth': [int(x) for x in np.linspace(5,10,5)],
              'min_samples_split': [int(x) for x in np.linspace(5,15,5)],
              'min_samples_leaf': [int(x) for x in np.linspace(1,10,5)],
                'max_features': [int(x) for x in np.linspace(3,9,5)]}

  # build a decision tree model
  dt_model = DecisionTreeRegressor()

  # random search
  dt_grid = RandomizedSearchCV(estimator=dt_model,
                       param_distributions= param_dict,
                       cv = 5, verbose=2, scoring='r2')

  dt_grid.fit(X_train,Y_train)

  print(dt_grid.best_estimator_)
  dt_optimal_model = dt_grid.best_estimator_
  print(dt_grid.best_params_)

  # predictions after modeling
  Y_train_pred = dt_optimal_model.predict(X_train)
  Y_test_pred = dt_optimal_model.predict(X_test)

  # Evaluating the decision tree regression model
  print("Train Set Metrics:")
  print("----------------------------------------------")
  print_metrics(Y_train, Y_train_pred)
  print("\n")

  print("Test Set Metrics")
  print("----------------------------------------------")
  metrics = print_metrics(Y_test, Y_test_pred)
  print("\n")
  r2_dt = metrics[3]

  # prediction in a dataframe
  pred = pd.DataFrame({'Actual Value': Y_test,
                       'Predicted Value': Y_test_pred})
  print("The top 5 rows of actual vs predicted values\n", pred.head())


  # calculate the feature importances
  features = X_train.columns
  importances = dt_optimal_model.feature_importances_
  indices = np.argsort(importances)

  importance_dict = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances}

  importance_df = pd.DataFrame(importance_dict)

  plt.figure(figsize=(15,25))
  plt.title('Feature Importance')
  plt.barh(range(len(indices)), importances[indices], color='blue', align='center')
  plt.yticks(range(len(indices)), [features[i] for i in indices])
  plt.xlabel('Relative Importance')
  plt.show()

  importance_df['Feature Importance'] = round(importance_df['Feature Importance'],2)
  pd.set_option('display.max_columns', 200)
  pd.set_option('display.max_rows', 200)
  print(importance_df.sort_values(by=['Feature Importance'],ascending=False))

  return Y_test, Y_test_pred, r2_dt

# %%
# Run the model
dt = decision_tree(X,Y)
# Out:
# The shape of training set is (896, 9) (896,)
# The shape of testing set is (442, 9) (442,)
#
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=6, max_features=9, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=9, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=9, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=9, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=9, min_samples_leaf=3, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=7, max_features=6, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_features=6, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_features=6, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_features=6, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_features=6, min_samples_leaf=5, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=7, max_features=7, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_features=7, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_features=7, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_features=7, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=7, max_features=7, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=3, min_samples_split=15; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=10, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=7, min_samples_split=5; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=1, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=1, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=1, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=1, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=8, max_features=3, min_samples_leaf=1, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=3, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_features=3, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_features=3, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_features=3, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=6, max_features=3, min_samples_leaf=1, min_samples_split=12; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_leaf=3, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_leaf=3, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_leaf=3, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_leaf=3, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=5, max_features=7, min_samples_leaf=3, min_samples_split=10; total time=   0.0s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# [CV] END max_depth=6, max_features=4, min_samples_leaf=5, min_samples_split=7; total time=   0.0s
# DecisionTreeRegressor(max_depth=5, max_features=7, min_samples_leaf=3,
#                       min_samples_split=10)
# {'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 7, 'max_depth': 5}
# Train Set Metrics:
# ----------------------------------------------
# MSE is 18299686.336982552
# RMSE is 4277.813265791595
# MAE is 2476.9630769621285
# R2 score is 0.8791523388683257
# Adjusted R2 score is 0.8779247666897873
#
#
# Test Set Metrics
# ----------------------------------------------
# MSE is 21146713.669151884
# RMSE is 4598.555606834811
# MAE is 2617.922019567127
# R2 score is 0.8451394290487871
# Adjusted R2 score is 0.8419131671539702
#
#
# The top 5 rows of actual vs predicted values
#        Actual Value  Predicted Value
# 559      1646.4297      2595.290397
# 1087    11353.2276     12705.068890
# 1020     8798.5930      9256.310575
# 460     10381.4787     10138.429225
# 802      2103.0800      3658.107063
#             Feature  Feature Importance
# 4            smoker                0.72
# 2               bmi                0.17
# 0               age                0.11
# 3          children                0.01
# 1               sex                0.00
# 5  region_northeast                0.00
# 6  region_northwest                0.00
# 7  region_southeast                0.00
# 8  region_southwest                0.00

# %%
# Save the r2 score
r2_dt = dt[2]
print(r2_dt)
# Out:
# 0.8451394290487871

# %% [markdown]
# ### **Building a Random Forest Regression Model**

# %%
def random_forest(X,Y):

  # split the data into train and test set
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
  print("The shape of training set is", X_train.shape, Y_train.shape)
  print("The shape of testing set is", X_test.shape, Y_test.shape)
  print("\n")

  # hyperparameters
  param_dict = {'n_estimators': [int(x) for x in np.linspace(10,300,100)],
              'max_depth': [int(x) for x in np.linspace(2,10,5)],
              'min_samples_split': [int(x) for x in np.linspace(5,25,10)],
              'min_samples_leaf': [int(x) for x in np.linspace(1,10,5)],
                'max_features': [int(x) for x in np.linspace(3,9,6)]}

  # build a random forest model
  rf_model = RandomForestRegressor()

  # random search
  rf_grid = RandomizedSearchCV(estimator=rf_model,
                       param_distributions= param_dict,
                       cv = 5, verbose=2, scoring='r2')

  rf_grid.fit(X_train,Y_train)

  print(rf_grid.best_estimator_)
  rf_optimal_model = rf_grid.best_estimator_
  print(rf_grid.best_params_)

  # predictions after modeling
  Y_train_pred = rf_optimal_model.predict(X_train)
  Y_test_pred = rf_optimal_model.predict(X_test)

  # Evaluating the random forest regression model
  print("Train Set Metrics:")
  print("----------------------------------------------")
  print_metrics(Y_train, Y_train_pred)
  print("\n")

  print("Test Set Metrics")
  print("----------------------------------------------")
  metrics = print_metrics(Y_test, Y_test_pred)
  print("\n")
  r2_rf = metrics[3]

  # prediction in a dataframe
  pred = pd.DataFrame({'Actual Value': Y_test,
                       'Predicted Value': Y_test_pred})
  print("The top 5 rows of actual vs predicted values\n", pred.head())


  # calculate the feature importances
  features = X_train.columns
  importances = rf_optimal_model.feature_importances_
  indices = np.argsort(importances)

  importance_dict = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances}

  importance_df = pd.DataFrame(importance_dict)

  plt.figure(figsize=(15,25))
  plt.title('Feature Importance')
  plt.barh(range(len(indices)), importances[indices], color='blue', align='center')
  plt.yticks(range(len(indices)), [features[i] for i in indices])
  plt.xlabel('Relative Importance')
  plt.show()

  importance_df['Feature Importance'] = round(importance_df['Feature Importance'],2)
  pd.set_option('display.max_columns', 200)
  pd.set_option('display.max_rows', 200)
  print(importance_df.sort_values(by=['Feature Importance'],ascending=False))

  return Y_test, Y_test_pred, r2_rf

# %%
# Run the model
rf = random_forest(X,Y)
# Out:
# The shape of training set is (896, 9) (896,)
# The shape of testing set is (442, 9) (442,)
#
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=6, max_features=7, min_samples_leaf=7, min_samples_split=22, n_estimators=229; total time=   0.6s
# [CV] END max_depth=6, max_features=7, min_samples_leaf=7, min_samples_split=22, n_estimators=229; total time=   0.7s
# [CV] END max_depth=6, max_features=7, min_samples_leaf=7, min_samples_split=22, n_estimators=229; total time=   0.6s
# [CV] END max_depth=6, max_features=7, min_samples_leaf=7, min_samples_split=22, n_estimators=229; total time=   0.7s
# [CV] END max_depth=6, max_features=7, min_samples_leaf=7, min_samples_split=22, n_estimators=229; total time=   0.5s
# [CV] END max_depth=8, max_features=9, min_samples_leaf=1, min_samples_split=16, n_estimators=112; total time=   0.2s
# [CV] END max_depth=8, max_features=9, min_samples_leaf=1, min_samples_split=16, n_estimators=112; total time=   0.2s
# [CV] END max_depth=8, max_features=9, min_samples_leaf=1, min_samples_split=16, n_estimators=112; total time=   0.2s
# [CV] END max_depth=8, max_features=9, min_samples_leaf=1, min_samples_split=16, n_estimators=112; total time=   0.2s
# [CV] END max_depth=8, max_features=9, min_samples_leaf=1, min_samples_split=16, n_estimators=112; total time=   0.2s
# [CV] END max_depth=10, max_features=6, min_samples_leaf=5, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END max_depth=10, max_features=6, min_samples_leaf=5, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END max_depth=10, max_features=6, min_samples_leaf=5, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END max_depth=10, max_features=6, min_samples_leaf=5, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END max_depth=10, max_features=6, min_samples_leaf=5, min_samples_split=5, n_estimators=48; total time=   0.1s
# [CV] END max_depth=4, max_features=7, min_samples_leaf=10, min_samples_split=20, n_estimators=226; total time=   0.4s
# [CV] END max_depth=4, max_features=7, min_samples_leaf=10, min_samples_split=20, n_estimators=226; total time=   0.4s
# [CV] END max_depth=4, max_features=7, min_samples_leaf=10, min_samples_split=20, n_estimators=226; total time=   0.4s
# [CV] END max_depth=4, max_features=7, min_samples_leaf=10, min_samples_split=20, n_estimators=226; total time=   0.4s
# [CV] END max_depth=4, max_features=7, min_samples_leaf=10, min_samples_split=20, n_estimators=226; total time=   0.4s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=10, min_samples_split=22, n_estimators=215; total time=   0.3s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=10, min_samples_split=22, n_estimators=215; total time=   0.3s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=10, min_samples_split=22, n_estimators=215; total time=   0.3s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=10, min_samples_split=22, n_estimators=215; total time=   0.3s
# [CV] END max_depth=10, max_features=3, min_samples_leaf=10, min_samples_split=22, n_estimators=215; total time=   0.3s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=5, min_samples_split=20, n_estimators=45; total time=   0.1s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=5, min_samples_split=20, n_estimators=45; total time=   0.1s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=5, min_samples_split=20, n_estimators=45; total time=   0.1s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=5, min_samples_split=20, n_estimators=45; total time=   0.1s
# [CV] END max_depth=2, max_features=5, min_samples_leaf=5, min_samples_split=20, n_estimators=45; total time=   0.1s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=1, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=1, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=1, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=1, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END max_depth=6, max_features=6, min_samples_leaf=1, min_samples_split=13, n_estimators=133; total time=   0.2s
# [CV] END max_depth=4, max_features=3, min_samples_leaf=5, min_samples_split=25, n_estimators=273; total time=   0.4s
# [CV] END max_depth=4, max_features=3, min_samples_leaf=5, min_samples_split=25, n_estimators=273; total time=   0.4s
# [CV] END max_depth=4, max_features=3, min_samples_leaf=5, min_samples_split=25, n_estimators=273; total time=   0.4s
# [CV] END max_depth=4, max_features=3, min_samples_leaf=5, min_samples_split=25, n_estimators=273; total time=   0.4s
# [CV] END max_depth=4, max_features=3, min_samples_leaf=5, min_samples_split=25, n_estimators=273; total time=   0.4s
# [CV] END max_depth=4, max_features=5, min_samples_leaf=1, min_samples_split=18, n_estimators=83; total time=   0.1s
# [CV] END max_depth=4, max_features=5, min_samples_leaf=1, min_samples_split=18, n_estimators=83; total time=   0.1s
# [CV] END max_depth=4, max_features=5, min_samples_leaf=1, min_samples_split=18, n_estimators=83; total time=   0.1s
# [CV] END max_depth=4, max_features=5, min_samples_leaf=1, min_samples_split=18, n_estimators=83; total time=   0.1s
# [CV] END max_depth=4, max_features=5, min_samples_leaf=1, min_samples_split=18, n_estimators=83; total time=   0.1s
# [CV] END max_depth=2, max_features=4, min_samples_leaf=3, min_samples_split=13, n_estimators=106; total time=   0.1s
# [CV] END max_depth=2, max_features=4, min_samples_leaf=3, min_samples_split=13, n_estimators=106; total time=   0.1s
# [CV] END max_depth=2, max_features=4, min_samples_leaf=3, min_samples_split=13, n_estimators=106; total time=   0.1s
# [CV] END max_depth=2, max_features=4, min_samples_leaf=3, min_samples_split=13, n_estimators=106; total time=   0.2s
# [CV] END max_depth=2, max_features=4, min_samples_leaf=3, min_samples_split=13, n_estimators=106; total time=   0.3s
# RandomForestRegressor(max_depth=6, max_features=7, min_samples_leaf=7,
#                       min_samples_split=22, n_estimators=229)
# {'n_estimators': 229, 'min_samples_split': 22, 'min_samples_leaf': 7, 'max_features': 7, 'max_depth': 6}
# Train Set Metrics:
# ----------------------------------------------
# MSE is 16910217.99014167
# RMSE is 4112.2035443472
# MAE is 2281.114621128286
# R2 score is 0.8883281245533988
# Adjusted R2 score is 0.8871937601301263
#
#
# Test Set Metrics
# ----------------------------------------------
# MSE is 19756621.48803446
# RMSE is 4444.8421218345275
# MAE is 2471.319534946075
# R2 score is 0.8553192835742064
# Adjusted R2 score is 0.8523051019820024
#
#
# The top 5 rows of actual vs predicted values
#        Actual Value  Predicted Value
# 559      1646.4297      2838.916821
# 1087    11353.2276     12429.739486
# 1020     8798.5930     10041.051196
# 460     10381.4787     11040.560741
# 802      2103.0800      3251.730785
#             Feature  Feature Importance
# 4            smoker                0.72
# 2               bmi                0.15
# 0               age                0.12
# 3          children                0.01
# 1               sex                0.00
# 5  region_northeast                0.00
# 6  region_northwest                0.00
# 7  region_southeast                0.00
# 8  region_southwest                0.00

# %%
# Save the r2 score
r2_rf = rf[2]
print(r2_rf)
# Out:
# 0.8553192835742064

# %% [markdown]
# ### **Building a XGBoost Regression Model**

# %%
def XGB(X,Y):

  # split the data into train and test set
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
  print("The shape of training set is", X_train.shape, Y_train.shape)
  print("The shape of testing set is", X_test.shape, Y_test.shape)
  print("\n")


  # hyperparameters
  param_dict = {'n_estimators': [int(x) for x in np.linspace(10,300,100)],
                'max_depth': [int(x) for x in np.linspace(5,10,5)],
                'learning_rate': [0.01,0.02,0.05,0.06,0.07,0.08,0.09,0.1,0.2,0.5]}

  # build a xgboost model
  xgb_model = XGBRegressor()

  # random search
  xgb_grid = RandomizedSearchCV(estimator=xgb_model,
                       param_distributions = param_dict,
                       cv = 5, verbose=2, scoring='r2')

  xgb_grid.fit(X_train,Y_train)

  print(xgb_grid.best_estimator_)
  xgb_optimal_model = xgb_grid.best_estimator_
  print(xgb_grid.best_params_)
  print("\n")

  # predictions after modeling
  Y_train_pred = xgb_optimal_model.predict(X_train)
  Y_test_pred = xgb_optimal_model.predict(X_test)

  # Evaluating the xgboost regression model
  print("Train Set Metrics:")
  print("----------------------------------------------")
  print_metrics(Y_train, Y_train_pred)
  print("\n")

  print("Test Set Metrics")
  print("----------------------------------------------")
  metrics = print_metrics(Y_test, Y_test_pred)
  print("\n")
  r2_xgb = metrics[3]

  # prediction in a dataframe
  pred = pd.DataFrame({'Actual Value': Y_test,
                       'Predicted Value': Y_test_pred})
  print("The top 5 rows of actual vs predicted values\n", pred.head())


  # calculate the feature importances
  features = X_train.columns
  importances = xgb_optimal_model.feature_importances_
  indices = np.argsort(importances)

  importance_dict = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances}

  importance_df = pd.DataFrame(importance_dict)

  plt.figure(figsize=(15,25))
  plt.title('Feature Importance')
  plt.barh(range(len(indices)), importances[indices], color='blue', align='center')
  plt.yticks(range(len(indices)), [features[i] for i in indices])
  plt.xlabel('Relative Importance')
  plt.show()

  importance_df['Feature Importance'] = round(importance_df['Feature Importance'],2)
  pd.set_option('display.max_columns', 200)
  pd.set_option('display.max_rows', 200)
  print(importance_df.sort_values(by=['Feature Importance'],ascending=False))

  return Y_test, Y_test_pred, r2_xgb

# %%
# Run the model
xgb = XGB(X,Y)
# Out:
# The shape of training set is (896, 9) (896,)
# The shape of testing set is (442, 9) (442,)
#
#
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=33; total time=   0.2s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=33; total time=   1.7s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=33; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=33; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=33; total time=   0.0s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=200; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=8, n_estimators=200; total time=   0.2s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=39; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=39; total time=   0.1s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=39; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=39; total time=   0.0s
# [CV] END ....learning_rate=0.2, max_depth=5, n_estimators=39; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=97; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=97; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=97; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=97; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=7, n_estimators=97; total time=   0.1s
# [CV] END ..learning_rate=0.06, max_depth=5, n_estimators=141; total time=   0.1s
# [CV] END ..learning_rate=0.06, max_depth=5, n_estimators=141; total time=   0.1s
# [CV] END ..learning_rate=0.06, max_depth=5, n_estimators=141; total time=   0.1s
# [CV] END ..learning_rate=0.06, max_depth=5, n_estimators=141; total time=   0.1s
# [CV] END ..learning_rate=0.06, max_depth=5, n_estimators=141; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=6, n_estimators=68; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=6, n_estimators=68; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=6, n_estimators=68; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=6, n_estimators=68; total time=   0.1s
# [CV] END ....learning_rate=0.5, max_depth=6, n_estimators=68; total time=   0.1s
# [CV] END ...learning_rate=0.5, max_depth=8, n_estimators=217; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=8, n_estimators=217; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=8, n_estimators=217; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=8, n_estimators=217; total time=   0.3s
# [CV] END ...learning_rate=0.5, max_depth=8, n_estimators=217; total time=   0.3s
# [CV] END ...learning_rate=0.06, max_depth=8, n_estimators=80; total time=   0.1s
# [CV] END ...learning_rate=0.06, max_depth=8, n_estimators=80; total time=   0.1s
# [CV] END ...learning_rate=0.06, max_depth=8, n_estimators=80; total time=   0.1s
# [CV] END ...learning_rate=0.06, max_depth=8, n_estimators=80; total time=   0.1s
# [CV] END ...learning_rate=0.06, max_depth=8, n_estimators=80; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=159; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=159; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=159; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=159; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=159; total time=   0.2s
# [CV] END ..learning_rate=0.09, max_depth=7, n_estimators=291; total time=   0.3s
# [CV] END ..learning_rate=0.09, max_depth=7, n_estimators=291; total time=   0.3s
# [CV] END ..learning_rate=0.09, max_depth=7, n_estimators=291; total time=   0.3s
# [CV] END ..learning_rate=0.09, max_depth=7, n_estimators=291; total time=   0.3s
# [CV] END ..learning_rate=0.09, max_depth=7, n_estimators=291; total time=   0.3s
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=159, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)
# {'n_estimators': 159, 'max_depth': 5, 'learning_rate': 0.05}
#
#
# Train Set Metrics:
# ----------------------------------------------
# MSE is 8937012.620928088
# RMSE is 2989.483671293103
# MAE is 1601.3496732756435
# R2 score is 0.9409816620429845
# Adjusted R2 score is 0.9403821529666717
#
#
# Test Set Metrics
# ----------------------------------------------
# MSE is 20925640.84307807
# RMSE is 4574.455250964651
# MAE is 2491.743585213905
# R2 score is 0.846758378669197
# Adjusted R2 score is 0.843565844891472
#
#
# The top 5 rows of actual vs predicted values
#        Actual Value  Predicted Value
# 559      1646.4297      2716.256836
# 1087    11353.2276     12118.305664
# 1020     8798.5930      8760.328125
# 460     10381.4787     11360.846680
# 802      2103.0800      3162.190430
#             Feature  Feature Importance
# 4            smoker                0.94
# 0               age                0.02
# 2               bmi                0.02
# 3          children                0.01
# 6  region_northwest                0.01
# 7  region_southeast                0.01
# 1               sex                0.00
# 5  region_northeast                0.00
# 8  region_southwest                0.00

# %%
# Save the r2 score
r2_xgb = xgb[2]
print(r2_xgb)
# Out:
# 0.846758378669197

# %% [markdown]
# ### **Building a CatBoost Regression Model:**

# %%
# Import Catboost
# !pip install catboost
import catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.1-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.1

# %%
# Import the library
from catboost import CatBoostRegressor

# %%
def catboost(X,Y):

  # split the data into train and test set
  X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
  print("The shape of training set is", X_train.shape, Y_train.shape)
  print("The shape of testing set is", X_test.shape, Y_test.shape)
  print("\n")


  # hyperparameters
  param_dict = {'n_estimators': [int(x) for x in np.linspace(10,300,100)],
                'max_depth': [int(x) for x in np.linspace(5,10,5)],
                'learning_rate': [0.01,0.02,0.05,0.06,0.07,0.08,0.09,0.1,0.2,0.5]}

  # build a catboost model
  cb_model = CatBoostRegressor()

  # random search
  cb_grid = RandomizedSearchCV(estimator=cb_model,
                       param_distributions = param_dict,
                       cv = 5, verbose=2, scoring='r2')

  cb_grid.fit(X_train,Y_train)

  print(cb_grid.best_estimator_)
  cb_optimal_model = cb_grid.best_estimator_
  print(cb_grid.best_params_)
  print("\n")

  # predictions after modeling
  Y_train_pred = cb_optimal_model.predict(X_train)
  Y_test_pred = cb_optimal_model.predict(X_test)

  # Evaluating the catboost regression model
  print("Train Set Metrics:")
  print("----------------------------------------------")
  print_metrics(Y_train, Y_train_pred)
  print("\n")

  print("Test Set Metrics")
  print("----------------------------------------------")
  metrics = print_metrics(Y_test, Y_test_pred)
  print("\n")
  r2_cb = metrics[3]

  # prediction in a dataframe
  pred = pd.DataFrame({'Actual Value': Y_test,
                       'Predicted Value': Y_test_pred})
  print("The top 5 rows of actual vs predicted values\n", pred.head())


  # calculate the feature importances
  features = X_train.columns
  importances = cb_optimal_model.feature_importances_
  indices = np.argsort(importances)

  importance_dict = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances}

  importance_df = pd.DataFrame(importance_dict)

  plt.figure(figsize=(15,25))
  plt.title('Feature Importance')
  plt.barh(range(len(indices)), importances[indices], color='blue', align='center')
  plt.yticks(range(len(indices)), [features[i] for i in indices])
  plt.xlabel('Relative Importance')
  plt.show()

  importance_df['Feature Importance'] = round(importance_df['Feature Importance'],2)
  pd.set_option('display.max_columns', 200)
  pd.set_option('display.max_rows', 200)
  print(importance_df.sort_values(by=['Feature Importance'],ascending=False))

  return Y_test, Y_test_pred, r2_cb

# %%
# Run the model
cb = catboost(X,Y)
# Out:
# Streaming output truncated to the last 5000 lines.
# 174:	learn: 3309.2086469	total: 554ms	remaining: 108ms
# 175:	learn: 3308.0687451	total: 555ms	remaining: 104ms
# 176:	learn: 3304.7513243	total: 565ms	remaining: 102ms
# 177:	learn: 3300.7116103	total: 567ms	remaining: 98.7ms
# 178:	learn: 3297.1947843	total: 580ms	remaining: 97.2ms
# 179:	learn: 3291.6012269	total: 581ms	remaining: 93.6ms
# 180:	learn: 3290.0028558	total: 582ms	remaining: 90.1ms
# 181:	learn: 3284.1355116	total: 596ms	remaining: 88.4ms
# 182:	learn: 3282.6023267	total: 597ms	remaining: 84.8ms
# 183:	learn: 3279.9003163	total: 612ms	remaining: 83.2ms
# 184:	learn: 3272.5180320	total: 629ms	remaining: 81.7ms
# 185:	learn: 3271.2570582	total: 631ms	remaining: 78ms
# 186:	learn: 3270.1585202	total: 640ms	remaining: 75.3ms
# 187:	learn: 3260.5395931	total: 641ms	remaining: 71.6ms
# 188:	learn: 3259.3418116	total: 655ms	remaining: 69.3ms
# 189:	learn: 3255.7990243	total: 656ms	remaining: 65.6ms
# 190:	learn: 3248.8710238	total: 670ms	remaining: 63.2ms
# 191:	learn: 3239.9939108	total: 674ms	remaining: 59.7ms
# 192:	learn: 3237.8945903	total: 676ms	remaining: 56ms
# 193:	learn: 3236.4278787	total: 690ms	remaining: 53.4ms
# 194:	learn: 3229.5449800	total: 699ms	remaining: 50.2ms
# 195:	learn: 3223.0996670	total: 708ms	remaining: 46.9ms
# 196:	learn: 3216.9462621	total: 719ms	remaining: 43.8ms
# 197:	learn: 3212.1140158	total: 725ms	remaining: 40.3ms
# 198:	learn: 3206.4689074	total: 727ms	remaining: 36.5ms
# 199:	learn: 3205.8243707	total: 729ms	remaining: 32.8ms
# 200:	learn: 3202.3944206	total: 748ms	remaining: 29.8ms
# 201:	learn: 3199.8712789	total: 763ms	remaining: 26.4ms
# 202:	learn: 3196.0458961	total: 764ms	remaining: 22.6ms
# 203:	learn: 3191.4490316	total: 772ms	remaining: 18.9ms
# 204:	learn: 3185.3475800	total: 778ms	remaining: 15.2ms
# 205:	learn: 3180.7279975	total: 783ms	remaining: 11.4ms
# 206:	learn: 3176.4159773	total: 793ms	remaining: 7.66ms
# 207:	learn: 3168.2645441	total: 801ms	remaining: 3.85ms
# 208:	learn: 3167.2159513	total: 811ms	remaining: 0us
# [CV] END ..learning_rate=0.06, max_depth=7, n_estimators=209; total time=   1.2s
# 0:	learn: 11781.9866506	total: 1.78ms	remaining: 370ms
# 1:	learn: 11308.0133772	total: 3.83ms	remaining: 397ms
# 2:	learn: 10826.5286809	total: 6.55ms	remaining: 450ms
# 3:	learn: 10403.9475226	total: 8.47ms	remaining: 434ms
# 4:	learn: 10026.6376557	total: 10.2ms	remaining: 418ms
# 5:	learn: 9688.2929348	total: 22.4ms	remaining: 759ms
# 6:	learn: 9347.3289519	total: 24.6ms	remaining: 709ms
# 7:	learn: 8990.9805613	total: 28.4ms	remaining: 713ms
# 8:	learn: 8734.1702051	total: 30.2ms	remaining: 671ms
# 9:	learn: 8432.2282597	total: 36.5ms	remaining: 727ms
# 10:	learn: 8148.4576057	total: 41.5ms	remaining: 747ms
# 11:	learn: 7872.2521313	total: 43.6ms	remaining: 716ms
# 12:	learn: 7667.2051565	total: 50.3ms	remaining: 759ms
# 13:	learn: 7439.9895936	total: 52.4ms	remaining: 729ms
# 14:	learn: 7208.6145273	total: 69.9ms	remaining: 904ms
# 15:	learn: 7019.3916010	total: 74.2ms	remaining: 895ms
# 16:	learn: 6804.7793911	total: 78.4ms	remaining: 886ms
# 17:	learn: 6632.9896510	total: 87.2ms	remaining: 925ms
# 18:	learn: 6460.7706507	total: 98.3ms	remaining: 983ms
# 19:	learn: 6274.8622851	total: 109ms	remaining: 1.03s
# 20:	learn: 6103.3626335	total: 109ms	remaining: 977ms
# 21:	learn: 5970.0189173	total: 113ms	remaining: 960ms
# 22:	learn: 5844.2207535	total: 118ms	remaining: 953ms
# 23:	learn: 5744.0498552	total: 119ms	remaining: 917ms
# 24:	learn: 5623.8177094	total: 120ms	remaining: 880ms
# 25:	learn: 5513.7729087	total: 120ms	remaining: 845ms
# 26:	learn: 5409.1852399	total: 122ms	remaining: 821ms
# 27:	learn: 5315.7893789	total: 134ms	remaining: 863ms
# 28:	learn: 5245.6658389	total: 139ms	remaining: 862ms
# 29:	learn: 5176.3692259	total: 141ms	remaining: 843ms
# 30:	learn: 5106.1242845	total: 147ms	remaining: 843ms
# 31:	learn: 5044.5860937	total: 156ms	remaining: 862ms
# 32:	learn: 4987.9572912	total: 157ms	remaining: 838ms
# 33:	learn: 4919.2625203	total: 170ms	remaining: 874ms
# 34:	learn: 4872.2144255	total: 180ms	remaining: 894ms
# 35:	learn: 4817.1404245	total: 181ms	remaining: 870ms
# 36:	learn: 4761.0050177	total: 182ms	remaining: 847ms
# 37:	learn: 4721.7198461	total: 184ms	remaining: 826ms
# 38:	learn: 4678.4880299	total: 185ms	remaining: 807ms
# 39:	learn: 4647.9401793	total: 186ms	remaining: 784ms
# 40:	learn: 4608.9097263	total: 187ms	remaining: 765ms
# 41:	learn: 4578.4759865	total: 188ms	remaining: 748ms
# 42:	learn: 4558.5688101	total: 188ms	remaining: 727ms
# 43:	learn: 4526.4872612	total: 189ms	remaining: 709ms
# 44:	learn: 4498.2355160	total: 190ms	remaining: 694ms
# 45:	learn: 4475.5826291	total: 191ms	remaining: 677ms
# 46:	learn: 4448.4355794	total: 192ms	remaining: 660ms
# 47:	learn: 4436.5457588	total: 192ms	remaining: 643ms
# 48:	learn: 4410.5561780	total: 193ms	remaining: 631ms
# 49:	learn: 4385.1755678	total: 195ms	remaining: 619ms
# 50:	learn: 4366.6285756	total: 207ms	remaining: 642ms
# 51:	learn: 4342.4026524	total: 213ms	remaining: 642ms
# 52:	learn: 4322.1653890	total: 214ms	remaining: 629ms
# 53:	learn: 4305.6393730	total: 223ms	remaining: 639ms
# 54:	learn: 4285.6021655	total: 228ms	remaining: 639ms
# 55:	learn: 4268.1582772	total: 233ms	remaining: 636ms
# 56:	learn: 4250.6981225	total: 235ms	remaining: 627ms
# 57:	learn: 4242.3082176	total: 236ms	remaining: 613ms
# 58:	learn: 4225.1703315	total: 237ms	remaining: 602ms
# 59:	learn: 4209.6160652	total: 240ms	remaining: 596ms
# 60:	learn: 4202.4758085	total: 241ms	remaining: 584ms
# 61:	learn: 4191.3906782	total: 248ms	remaining: 588ms
# 62:	learn: 4182.6905474	total: 249ms	remaining: 576ms
# 63:	learn: 4167.3663395	total: 250ms	remaining: 566ms
# 64:	learn: 4155.1601878	total: 251ms	remaining: 555ms
# 65:	learn: 4141.2936275	total: 256ms	remaining: 556ms
# 66:	learn: 4127.3212857	total: 257ms	remaining: 546ms
# 67:	learn: 4116.4180723	total: 259ms	remaining: 536ms
# 68:	learn: 4103.0707249	total: 260ms	remaining: 527ms
# 69:	learn: 4086.1574419	total: 263ms	remaining: 521ms
# 70:	learn: 4071.2981611	total: 264ms	remaining: 513ms
# 71:	learn: 4062.1221601	total: 272ms	remaining: 517ms
# 72:	learn: 4050.3531072	total: 283ms	remaining: 527ms
# 73:	learn: 4041.6234615	total: 284ms	remaining: 519ms
# 74:	learn: 4032.0854217	total: 285ms	remaining: 510ms
# 75:	learn: 4022.1396625	total: 289ms	remaining: 505ms
# 76:	learn: 4007.3835619	total: 292ms	remaining: 501ms
# 77:	learn: 4000.1691631	total: 293ms	remaining: 492ms
# 78:	learn: 3992.0022620	total: 299ms	remaining: 492ms
# 79:	learn: 3983.0147568	total: 300ms	remaining: 484ms
# 80:	learn: 3975.9908478	total: 302ms	remaining: 477ms
# 81:	learn: 3969.6005628	total: 303ms	remaining: 469ms
# 82:	learn: 3966.4637103	total: 303ms	remaining: 460ms
# 83:	learn: 3956.1907677	total: 306ms	remaining: 455ms
# 84:	learn: 3948.2342067	total: 307ms	remaining: 448ms
# 85:	learn: 3941.8174369	total: 308ms	remaining: 440ms
# 86:	learn: 3936.5896891	total: 309ms	remaining: 433ms
# 87:	learn: 3934.5407252	total: 309ms	remaining: 426ms
# 88:	learn: 3923.2565793	total: 311ms	remaining: 419ms
# 89:	learn: 3917.1000958	total: 312ms	remaining: 413ms
# 90:	learn: 3909.4250483	total: 313ms	remaining: 406ms
# 91:	learn: 3903.6154699	total: 314ms	remaining: 399ms
# 92:	learn: 3898.7894197	total: 315ms	remaining: 393ms
# 93:	learn: 3889.8167923	total: 316ms	remaining: 387ms
# 94:	learn: 3882.6339061	total: 317ms	remaining: 381ms
# 95:	learn: 3869.8264558	total: 318ms	remaining: 375ms
# 96:	learn: 3862.1702292	total: 319ms	remaining: 369ms
# 97:	learn: 3850.8589733	total: 320ms	remaining: 363ms
# 98:	learn: 3843.3183045	total: 321ms	remaining: 357ms
# 99:	learn: 3836.6216469	total: 322ms	remaining: 351ms
# 100:	learn: 3824.1176662	total: 323ms	remaining: 346ms
# 101:	learn: 3813.3476616	total: 325ms	remaining: 341ms
# 102:	learn: 3803.1607753	total: 326ms	remaining: 335ms
# 103:	learn: 3801.7156598	total: 326ms	remaining: 330ms
# 104:	learn: 3792.6770807	total: 328ms	remaining: 324ms
# 105:	learn: 3790.9535001	total: 328ms	remaining: 319ms
# 106:	learn: 3777.7197626	total: 329ms	remaining: 314ms
# 107:	learn: 3770.1607925	total: 330ms	remaining: 309ms
# 108:	learn: 3762.2851604	total: 331ms	remaining: 304ms
# 109:	learn: 3748.3148490	total: 333ms	remaining: 299ms
# 110:	learn: 3740.5800321	total: 334ms	remaining: 295ms
# 111:	learn: 3735.9804366	total: 335ms	remaining: 290ms
# 112:	learn: 3728.9161833	total: 336ms	remaining: 285ms
# 113:	learn: 3719.1586063	total: 337ms	remaining: 281ms
# 114:	learn: 3715.7134773	total: 338ms	remaining: 276ms
# 115:	learn: 3707.5088424	total: 339ms	remaining: 272ms
# 116:	learn: 3703.2559773	total: 340ms	remaining: 267ms
# 117:	learn: 3702.0869930	total: 341ms	remaining: 263ms
# 118:	learn: 3694.4663274	total: 342ms	remaining: 258ms
# 119:	learn: 3690.3144666	total: 343ms	remaining: 254ms
# 120:	learn: 3686.4755438	total: 344ms	remaining: 250ms
# 121:	learn: 3679.6571992	total: 345ms	remaining: 246ms
# 122:	learn: 3673.6806260	total: 346ms	remaining: 242ms
# 123:	learn: 3671.0657892	total: 347ms	remaining: 238ms
# 124:	learn: 3667.5475314	total: 348ms	remaining: 234ms
# 125:	learn: 3664.6310905	total: 349ms	remaining: 230ms
# 126:	learn: 3654.9880371	total: 350ms	remaining: 226ms
# 127:	learn: 3651.3229773	total: 351ms	remaining: 222ms
# 128:	learn: 3645.3089454	total: 352ms	remaining: 219ms
# 129:	learn: 3639.6068804	total: 354ms	remaining: 215ms
# 130:	learn: 3630.0945977	total: 355ms	remaining: 211ms
# 131:	learn: 3626.5370642	total: 356ms	remaining: 208ms
# 132:	learn: 3610.2044321	total: 357ms	remaining: 204ms
# 133:	learn: 3606.4499462	total: 358ms	remaining: 201ms
# 134:	learn: 3601.3095784	total: 359ms	remaining: 197ms
# 135:	learn: 3597.9631813	total: 360ms	remaining: 193ms
# 136:	learn: 3589.5943486	total: 361ms	remaining: 190ms
# 137:	learn: 3582.6032064	total: 363ms	remaining: 187ms
# 138:	learn: 3579.3097465	total: 364ms	remaining: 183ms
# 139:	learn: 3571.5669067	total: 365ms	remaining: 180ms
# 140:	learn: 3564.9382362	total: 366ms	remaining: 177ms
# 141:	learn: 3563.7392552	total: 367ms	remaining: 173ms
# 142:	learn: 3556.1709934	total: 368ms	remaining: 170ms
# 143:	learn: 3553.9826719	total: 370ms	remaining: 167ms
# 144:	learn: 3553.3004330	total: 370ms	remaining: 163ms
# 145:	learn: 3551.7213872	total: 371ms	remaining: 160ms
# 146:	learn: 3549.8920569	total: 372ms	remaining: 157ms
# 147:	learn: 3544.9780475	total: 373ms	remaining: 154ms
# 148:	learn: 3542.2870518	total: 375ms	remaining: 151ms
# 149:	learn: 3539.1988934	total: 376ms	remaining: 148ms
# 150:	learn: 3531.9432182	total: 377ms	remaining: 145ms
# 151:	learn: 3529.0454498	total: 378ms	remaining: 142ms
# 152:	learn: 3524.9977780	total: 379ms	remaining: 139ms
# 153:	learn: 3517.5847551	total: 380ms	remaining: 136ms
# 154:	learn: 3512.6676129	total: 381ms	remaining: 133ms
# 155:	learn: 3505.1360680	total: 382ms	remaining: 130ms
# 156:	learn: 3502.2565567	total: 384ms	remaining: 127ms
# 157:	learn: 3497.5666717	total: 386ms	remaining: 125ms
# 158:	learn: 3496.1498701	total: 387ms	remaining: 122ms
# 159:	learn: 3494.2489000	total: 395ms	remaining: 121ms
# 160:	learn: 3488.3941675	total: 399ms	remaining: 119ms
# 161:	learn: 3481.3544454	total: 401ms	remaining: 116ms
# 162:	learn: 3475.3269111	total: 402ms	remaining: 114ms
# 163:	learn: 3471.3756486	total: 405ms	remaining: 111ms
# 164:	learn: 3467.1024798	total: 406ms	remaining: 108ms
# 165:	learn: 3463.6198368	total: 407ms	remaining: 105ms
# 166:	learn: 3454.3840760	total: 408ms	remaining: 103ms
# 167:	learn: 3450.8175605	total: 409ms	remaining: 99.9ms
# 168:	learn: 3447.7525027	total: 410ms	remaining: 97.2ms
# 169:	learn: 3433.4695650	total: 412ms	remaining: 94.5ms
# 170:	learn: 3427.8904168	total: 413ms	remaining: 91.8ms
# 171:	learn: 3420.3155209	total: 414ms	remaining: 89.1ms
# 172:	learn: 3418.5083349	total: 415ms	remaining: 86.4ms
# 173:	learn: 3413.3625627	total: 416ms	remaining: 83.7ms
# 174:	learn: 3403.7448192	total: 417ms	remaining: 81ms
# 175:	learn: 3399.7215667	total: 418ms	remaining: 78.4ms
# 176:	learn: 3398.0224763	total: 419ms	remaining: 75.8ms
# 177:	learn: 3391.0544321	total: 421ms	remaining: 73.3ms
# 178:	learn: 3382.6351269	total: 422ms	remaining: 70.7ms
# 179:	learn: 3375.4174916	total: 423ms	remaining: 68.2ms
# 180:	learn: 3373.5483962	total: 424ms	remaining: 65.6ms
# 181:	learn: 3372.0562748	total: 425ms	remaining: 63.1ms
# 182:	learn: 3366.3544399	total: 426ms	remaining: 60.5ms
# 183:	learn: 3359.5813350	total: 427ms	remaining: 58ms
# 184:	learn: 3354.9281743	total: 428ms	remaining: 55.6ms
# 185:	learn: 3349.0731051	total: 430ms	remaining: 53.1ms
# 186:	learn: 3346.3193001	total: 431ms	remaining: 50.7ms
# 187:	learn: 3338.1939368	total: 432ms	remaining: 48.2ms
# 188:	learn: 3334.9684057	total: 433ms	remaining: 45.8ms
# 189:	learn: 3333.0370462	total: 434ms	remaining: 43.4ms
# 190:	learn: 3331.7297837	total: 435ms	remaining: 41ms
# 191:	learn: 3324.7771813	total: 436ms	remaining: 38.6ms
# 192:	learn: 3319.8428092	total: 437ms	remaining: 36.2ms
# 193:	learn: 3315.1242546	total: 438ms	remaining: 33.9ms
# 194:	learn: 3309.8117649	total: 440ms	remaining: 31.6ms
# 195:	learn: 3306.2936751	total: 441ms	remaining: 29.2ms
# 196:	learn: 3303.5939652	total: 442ms	remaining: 26.9ms
# 197:	learn: 3301.3252032	total: 443ms	remaining: 24.6ms
# 198:	learn: 3297.1373770	total: 447ms	remaining: 22.5ms
# 199:	learn: 3295.1753214	total: 448ms	remaining: 20.2ms
# 200:	learn: 3291.2591150	total: 450ms	remaining: 17.9ms
# 201:	learn: 3288.5543516	total: 451ms	remaining: 15.6ms
# 202:	learn: 3285.1598397	total: 452ms	remaining: 13.4ms
# 203:	learn: 3281.9222452	total: 453ms	remaining: 11.1ms
# 204:	learn: 3273.4837451	total: 454ms	remaining: 8.86ms
# 205:	learn: 3268.9190149	total: 455ms	remaining: 6.63ms
# 206:	learn: 3266.4760080	total: 456ms	remaining: 4.41ms
# 207:	learn: 3265.0287186	total: 457ms	remaining: 2.2ms
# 208:	learn: 3263.9934695	total: 458ms	remaining: 0us
# [CV] END ..learning_rate=0.06, max_depth=7, n_estimators=209; total time=   0.7s
# 0:	learn: 11490.8074838	total: 599us	remaining: 125ms
# 1:	learn: 11050.6859839	total: 2.02ms	remaining: 209ms
# 2:	learn: 10591.4766517	total: 3.35ms	remaining: 230ms
# 3:	learn: 10183.7389531	total: 4.11ms	remaining: 211ms
# 4:	learn: 9824.1937357	total: 5.06ms	remaining: 206ms
# 5:	learn: 9467.9044211	total: 6.54ms	remaining: 221ms
# 6:	learn: 9153.6375476	total: 7.83ms	remaining: 226ms
# 7:	learn: 8817.7509090	total: 8.67ms	remaining: 218ms
# 8:	learn: 8572.4570342	total: 9.98ms	remaining: 222ms
# 9:	learn: 8282.3690505	total: 11.5ms	remaining: 229ms
# 10:	learn: 8007.3063888	total: 12.8ms	remaining: 230ms
# 11:	learn: 7752.1214001	total: 13.3ms	remaining: 218ms
# 12:	learn: 7538.9534495	total: 14.7ms	remaining: 222ms
# 13:	learn: 7323.2241035	total: 16ms	remaining: 223ms
# 14:	learn: 7125.7629029	total: 16.6ms	remaining: 214ms
# 15:	learn: 6925.2853749	total: 17.1ms	remaining: 206ms
# 16:	learn: 6733.2264189	total: 18.7ms	remaining: 211ms
# 17:	learn: 6552.5610187	total: 20.6ms	remaining: 218ms
# 18:	learn: 6396.8541690	total: 22.9ms	remaining: 229ms
# 19:	learn: 6234.3809848	total: 25.5ms	remaining: 241ms
# 20:	learn: 6102.3160499	total: 26ms	remaining: 233ms
# 21:	learn: 5978.4966513	total: 27.2ms	remaining: 231ms
# 22:	learn: 5854.5187326	total: 28.3ms	remaining: 229ms
# 23:	learn: 5729.2813101	total: 29.4ms	remaining: 226ms
# 24:	learn: 5628.6499153	total: 29.8ms	remaining: 219ms
# 25:	learn: 5522.2699222	total: 30.8ms	remaining: 217ms
# 26:	learn: 5421.2505140	total: 31.9ms	remaining: 215ms
# 27:	learn: 5332.0304450	total: 32.9ms	remaining: 213ms
# 28:	learn: 5251.7994522	total: 34.1ms	remaining: 211ms
# 29:	learn: 5169.1783325	total: 35.5ms	remaining: 212ms
# 30:	learn: 5096.3827699	total: 36.7ms	remaining: 211ms
# 31:	learn: 5034.0394122	total: 38ms	remaining: 210ms
# 32:	learn: 4975.4783773	total: 40.8ms	remaining: 218ms
# 33:	learn: 4918.4034773	total: 43.2ms	remaining: 222ms
# 34:	learn: 4865.5139318	total: 45.7ms	remaining: 227ms
# 35:	learn: 4813.3712354	total: 48.1ms	remaining: 231ms
# 36:	learn: 4763.9272526	total: 50.5ms	remaining: 235ms
# 37:	learn: 4726.9248167	total: 52.9ms	remaining: 238ms
# 38:	learn: 4685.4042643	total: 55.5ms	remaining: 242ms
# 39:	learn: 4651.3894255	total: 57.1ms	remaining: 241ms
# 40:	learn: 4616.0924351	total: 58.6ms	remaining: 240ms
# 41:	learn: 4584.1341062	total: 74.1ms	remaining: 294ms
# 42:	learn: 4566.3133491	total: 85ms	remaining: 328ms
# 43:	learn: 4541.1667916	total: 86ms	remaining: 322ms
# 44:	learn: 4515.0767941	total: 89.8ms	remaining: 327ms
# 45:	learn: 4492.3180098	total: 90.6ms	remaining: 321ms
# 46:	learn: 4463.1591791	total: 92.1ms	remaining: 317ms
# 47:	learn: 4438.5218626	total: 95.2ms	remaining: 319ms
# 48:	learn: 4422.3224559	total: 95.9ms	remaining: 313ms
# 49:	learn: 4394.4578377	total: 102ms	remaining: 323ms
# 50:	learn: 4370.9767706	total: 107ms	remaining: 332ms
# 51:	learn: 4347.8306253	total: 109ms	remaining: 328ms
# 52:	learn: 4325.9666399	total: 110ms	remaining: 324ms
# 53:	learn: 4305.9557131	total: 111ms	remaining: 320ms
# 54:	learn: 4296.6539592	total: 112ms	remaining: 314ms
# 55:	learn: 4277.3698533	total: 113ms	remaining: 310ms
# 56:	learn: 4264.4600052	total: 116ms	remaining: 310ms
# 57:	learn: 4242.0878865	total: 123ms	remaining: 319ms
# 58:	learn: 4222.5710783	total: 124ms	remaining: 315ms
# 59:	learn: 4204.9195269	total: 125ms	remaining: 311ms
# 60:	learn: 4189.9753169	total: 127ms	remaining: 307ms
# 61:	learn: 4173.6091510	total: 128ms	remaining: 303ms
# 62:	learn: 4161.0649902	total: 129ms	remaining: 300ms
# 63:	learn: 4146.3040195	total: 136ms	remaining: 307ms
# 64:	learn: 4128.6815815	total: 137ms	remaining: 304ms
# 65:	learn: 4115.6977182	total: 138ms	remaining: 300ms
# 66:	learn: 4101.2824612	total: 140ms	remaining: 296ms
# 67:	learn: 4087.5574866	total: 141ms	remaining: 292ms
# 68:	learn: 4075.9053253	total: 146ms	remaining: 296ms
# 69:	learn: 4065.5172304	total: 147ms	remaining: 292ms
# 70:	learn: 4053.0631519	total: 149ms	remaining: 290ms
# 71:	learn: 4040.1793522	total: 163ms	remaining: 309ms
# 72:	learn: 4024.6689967	total: 164ms	remaining: 305ms
# 73:	learn: 4016.6121078	total: 165ms	remaining: 301ms
# 74:	learn: 4008.6216390	total: 167ms	remaining: 298ms
# 75:	learn: 4001.8935990	total: 168ms	remaining: 294ms
# 76:	learn: 3991.6400423	total: 170ms	remaining: 291ms
# 77:	learn: 3983.6563109	total: 171ms	remaining: 287ms
# 78:	learn: 3979.8754308	total: 172ms	remaining: 283ms
# 79:	learn: 3970.6342998	total: 173ms	remaining: 279ms
# 80:	learn: 3962.9533935	total: 175ms	remaining: 276ms
# 81:	learn: 3956.1773948	total: 181ms	remaining: 280ms
# 82:	learn: 3953.9957537	total: 182ms	remaining: 276ms
# 83:	learn: 3943.0155929	total: 183ms	remaining: 273ms
# 84:	learn: 3934.4529500	total: 184ms	remaining: 269ms
# 85:	learn: 3923.4452227	total: 186ms	remaining: 266ms
# 86:	learn: 3916.4858129	total: 190ms	remaining: 266ms
# 87:	learn: 3903.5293736	total: 191ms	remaining: 263ms
# 88:	learn: 3895.6943931	total: 192ms	remaining: 259ms
# 89:	learn: 3890.9763573	total: 194ms	remaining: 256ms
# 90:	learn: 3882.5752937	total: 195ms	remaining: 253ms
# 91:	learn: 3873.3391197	total: 197ms	remaining: 250ms
# 92:	learn: 3865.7126330	total: 198ms	remaining: 247ms
# 93:	learn: 3865.2456961	total: 198ms	remaining: 243ms
# 94:	learn: 3854.9544281	total: 200ms	remaining: 240ms
# 95:	learn: 3845.0622055	total: 201ms	remaining: 237ms
# 96:	learn: 3844.0683452	total: 204ms	remaining: 236ms
# 97:	learn: 3833.1419386	total: 206ms	remaining: 233ms
# 98:	learn: 3829.8104363	total: 208ms	remaining: 231ms
# 99:	learn: 3824.8516479	total: 212ms	remaining: 231ms
# 100:	learn: 3814.9200825	total: 214ms	remaining: 229ms
# 101:	learn: 3810.7318150	total: 217ms	remaining: 228ms
# 102:	learn: 3805.2504206	total: 220ms	remaining: 226ms
# 103:	learn: 3799.5324228	total: 223ms	remaining: 225ms
# 104:	learn: 3795.4338112	total: 225ms	remaining: 223ms
# 105:	learn: 3792.5797309	total: 228ms	remaining: 221ms
# 106:	learn: 3782.2308106	total: 230ms	remaining: 220ms
# 107:	learn: 3773.9390839	total: 236ms	remaining: 221ms
# 108:	learn: 3765.0215698	total: 239ms	remaining: 219ms
# 109:	learn: 3757.8548279	total: 242ms	remaining: 218ms
# 110:	learn: 3752.6758125	total: 245ms	remaining: 216ms
# 111:	learn: 3746.3052370	total: 247ms	remaining: 214ms
# 112:	learn: 3740.1437210	total: 250ms	remaining: 212ms
# 113:	learn: 3731.4814339	total: 252ms	remaining: 210ms
# 114:	learn: 3727.8565896	total: 255ms	remaining: 208ms
# 115:	learn: 3722.4578354	total: 267ms	remaining: 214ms
# 116:	learn: 3715.6263983	total: 270ms	remaining: 212ms
# 117:	learn: 3708.2267830	total: 272ms	remaining: 210ms
# 118:	learn: 3702.0801445	total: 278ms	remaining: 210ms
# 119:	learn: 3694.3203017	total: 280ms	remaining: 208ms
# 120:	learn: 3690.4388997	total: 283ms	remaining: 206ms
# 121:	learn: 3689.1752269	total: 285ms	remaining: 203ms
# 122:	learn: 3681.1710005	total: 286ms	remaining: 200ms
# 123:	learn: 3675.5707216	total: 289ms	remaining: 198ms
# 124:	learn: 3664.7321878	total: 292ms	remaining: 196ms
# 125:	learn: 3654.7253354	total: 295ms	remaining: 194ms
# 126:	learn: 3647.7570262	total: 298ms	remaining: 192ms
# 127:	learn: 3643.2602202	total: 300ms	remaining: 190ms
# 128:	learn: 3634.3951144	total: 303ms	remaining: 188ms
# 129:	learn: 3623.5298989	total: 305ms	remaining: 185ms
# 130:	learn: 3619.4612472	total: 308ms	remaining: 183ms
# 131:	learn: 3615.1714133	total: 310ms	remaining: 181ms
# 132:	learn: 3610.2913327	total: 313ms	remaining: 179ms
# 133:	learn: 3602.7692098	total: 315ms	remaining: 176ms
# 134:	learn: 3602.3577459	total: 317ms	remaining: 174ms
# 135:	learn: 3598.5816840	total: 319ms	remaining: 171ms
# 136:	learn: 3595.4626304	total: 321ms	remaining: 169ms
# 137:	learn: 3590.9371042	total: 324ms	remaining: 166ms
# 138:	learn: 3587.7924362	total: 326ms	remaining: 164ms
# 139:	learn: 3581.9775814	total: 328ms	remaining: 162ms
# 140:	learn: 3576.8740862	total: 331ms	remaining: 159ms
# 141:	learn: 3575.9637265	total: 332ms	remaining: 157ms
# 142:	learn: 3562.8379556	total: 334ms	remaining: 154ms
# 143:	learn: 3561.1290050	total: 336ms	remaining: 152ms
# 144:	learn: 3549.8553096	total: 339ms	remaining: 150ms
# 145:	learn: 3544.6813939	total: 341ms	remaining: 147ms
# 146:	learn: 3539.0945742	total: 344ms	remaining: 145ms
# 147:	learn: 3531.0218849	total: 346ms	remaining: 143ms
# 148:	learn: 3523.9780565	total: 349ms	remaining: 140ms
# 149:	learn: 3518.3642852	total: 351ms	remaining: 138ms
# 150:	learn: 3512.7771572	total: 354ms	remaining: 136ms
# 151:	learn: 3509.2859103	total: 356ms	remaining: 134ms
# 152:	learn: 3505.8666476	total: 358ms	remaining: 131ms
# 153:	learn: 3500.6482830	total: 361ms	remaining: 129ms
# 154:	learn: 3497.8438806	total: 364ms	remaining: 127ms
# 155:	learn: 3493.0234838	total: 365ms	remaining: 124ms
# 156:	learn: 3490.7968172	total: 368ms	remaining: 122ms
# 157:	learn: 3487.2701647	total: 370ms	remaining: 120ms
# 158:	learn: 3483.5691084	total: 373ms	remaining: 117ms
# 159:	learn: 3481.0758633	total: 375ms	remaining: 115ms
# 160:	learn: 3475.0347914	total: 378ms	remaining: 113ms
# 161:	learn: 3470.7003673	total: 380ms	remaining: 110ms
# 162:	learn: 3468.1933962	total: 383ms	remaining: 108ms
# 163:	learn: 3465.2777518	total: 385ms	remaining: 106ms
# 164:	learn: 3459.3920253	total: 388ms	remaining: 103ms
# 165:	learn: 3456.1251715	total: 395ms	remaining: 102ms
# 166:	learn: 3455.6617834	total: 403ms	remaining: 101ms
# 167:	learn: 3452.9006655	total: 404ms	remaining: 98.6ms
# 168:	learn: 3452.3024150	total: 406ms	remaining: 96.1ms
# 169:	learn: 3451.3323245	total: 408ms	remaining: 93.6ms
# 170:	learn: 3446.8907956	total: 410ms	remaining: 91.2ms
# 171:	learn: 3445.7537744	total: 413ms	remaining: 88.8ms
# 172:	learn: 3444.4419059	total: 415ms	remaining: 86.4ms
# 173:	learn: 3439.9753602	total: 418ms	remaining: 84.1ms
# 174:	learn: 3439.4207339	total: 420ms	remaining: 81.7ms
# 175:	learn: 3437.2413218	total: 423ms	remaining: 79.3ms
# 176:	learn: 3434.9614374	total: 425ms	remaining: 76.9ms
# 177:	learn: 3430.7671503	total: 428ms	remaining: 74.5ms
# 178:	learn: 3426.5064578	total: 430ms	remaining: 72.1ms
# 179:	learn: 3425.3266407	total: 433ms	remaining: 69.7ms
# 180:	learn: 3422.3756982	total: 435ms	remaining: 67.3ms
# 181:	learn: 3421.4520293	total: 449ms	remaining: 66.6ms
# 182:	learn: 3419.8660729	total: 454ms	remaining: 64.4ms
# 183:	learn: 3419.1594057	total: 456ms	remaining: 62ms
# 184:	learn: 3415.1748901	total: 459ms	remaining: 59.5ms
# 185:	learn: 3411.7685257	total: 461ms	remaining: 57ms
# 186:	learn: 3408.8162121	total: 463ms	remaining: 54.5ms
# 187:	learn: 3406.4486445	total: 470ms	remaining: 52.6ms
# 188:	learn: 3400.2233491	total: 473ms	remaining: 50.1ms
# 189:	learn: 3393.3156162	total: 476ms	remaining: 47.6ms
# 190:	learn: 3387.8165531	total: 478ms	remaining: 45.1ms
# 191:	learn: 3383.1027798	total: 484ms	remaining: 42.9ms
# 192:	learn: 3381.8405642	total: 487ms	remaining: 40.3ms
# 193:	learn: 3379.9497828	total: 489ms	remaining: 37.8ms
# 194:	learn: 3377.8554865	total: 492ms	remaining: 35.3ms
# 195:	learn: 3374.9833539	total: 494ms	remaining: 32.8ms
# 196:	learn: 3370.7903209	total: 498ms	remaining: 30.3ms
# 197:	learn: 3365.6724741	total: 499ms	remaining: 27.7ms
# 198:	learn: 3364.8276421	total: 502ms	remaining: 25.2ms
# 199:	learn: 3356.9649869	total: 505ms	remaining: 22.7ms
# 200:	learn: 3355.3700187	total: 507ms	remaining: 20.2ms
# 201:	learn: 3353.6980288	total: 510ms	remaining: 17.7ms
# 202:	learn: 3348.7095065	total: 512ms	remaining: 15.1ms
# 203:	learn: 3343.4635329	total: 515ms	remaining: 12.6ms
# 204:	learn: 3341.9864434	total: 518ms	remaining: 10.1ms
# 205:	learn: 3340.4210367	total: 520ms	remaining: 7.57ms
# 206:	learn: 3337.1334587	total: 523ms	remaining: 5.05ms
# 207:	learn: 3333.3351693	total: 525ms	remaining: 2.52ms
# 208:	learn: 3326.1981452	total: 528ms	remaining: 0us
# [CV] END ..learning_rate=0.06, max_depth=7, n_estimators=209; total time=   0.7s
# 0:	learn: 12176.9802389	total: 666us	remaining: 146ms
# 1:	learn: 12095.9068948	total: 1.5ms	remaining: 163ms
# 2:	learn: 12012.0625563	total: 2.33ms	remaining: 168ms
# 3:	learn: 11925.0538468	total: 6.04ms	remaining: 326ms
# 4:	learn: 11843.1975524	total: 7.43ms	remaining: 320ms
# 5:	learn: 11761.1663224	total: 9.05ms	remaining: 323ms
# 6:	learn: 11680.1766188	total: 10.7ms	remaining: 326ms
# 7:	learn: 11603.0568262	total: 12.4ms	remaining: 329ms
# 8:	learn: 11520.5784061	total: 14.1ms	remaining: 331ms
# 9:	learn: 11442.3042037	total: 17.7ms	remaining: 371ms
# 10:	learn: 11365.5688670	total: 18.2ms	remaining: 347ms
# 11:	learn: 11300.2807617	total: 19.5ms	remaining: 338ms
# 12:	learn: 11225.1547248	total: 20.9ms	remaining: 332ms
# 13:	learn: 11150.1138491	total: 21.9ms	remaining: 322ms
# 14:	learn: 11072.9843359	total: 23.2ms	remaining: 316ms
# 15:	learn: 11007.8073008	total: 23.9ms	remaining: 304ms
# 16:	learn: 10934.7177163	total: 25ms	remaining: 299ms
# 17:	learn: 10863.8822852	total: 26.3ms	remaining: 295ms
# 18:	learn: 10788.0032633	total: 43.2ms	remaining: 457ms
# 19:	learn: 10711.1559027	total: 44.5ms	remaining: 445ms
# 20:	learn: 10641.9241974	total: 46.2ms	remaining: 438ms
# 21:	learn: 10570.1617905	total: 52.1ms	remaining: 469ms
# 22:	learn: 10495.9454848	total: 53.8ms	remaining: 460ms
# 23:	learn: 10426.8228751	total: 55.1ms	remaining: 450ms
# 24:	learn: 10365.3442149	total: 59.3ms	remaining: 462ms
# 25:	learn: 10302.7513621	total: 60.7ms	remaining: 453ms
# 26:	learn: 10234.7298826	total: 62.1ms	remaining: 444ms
# 27:	learn: 10171.4950811	total: 63.4ms	remaining: 435ms
# 28:	learn: 10110.0393629	total: 65.2ms	remaining: 429ms
# 29:	learn: 10046.9034213	total: 66.9ms	remaining: 424ms
# 30:	learn: 9989.7632042	total: 68.7ms	remaining: 419ms
# 31:	learn: 9934.3281632	total: 70.4ms	remaining: 414ms
# 32:	learn: 9870.0136243	total: 72ms	remaining: 408ms
# 33:	learn: 9807.7417136	total: 73.8ms	remaining: 404ms
# 34:	learn: 9743.8751308	total: 79.6ms	remaining: 421ms
# 35:	learn: 9680.8581208	total: 82.3ms	remaining: 421ms
# 36:	learn: 9619.6686806	total: 83.5ms	remaining: 413ms
# 37:	learn: 9561.7685376	total: 84.6ms	remaining: 405ms
# 38:	learn: 9500.1320202	total: 86.5ms	remaining: 401ms
# 39:	learn: 9438.0568579	total: 88ms	remaining: 396ms
# 40:	learn: 9376.0943206	total: 89.4ms	remaining: 390ms
# 41:	learn: 9318.3238060	total: 90.6ms	remaining: 384ms
# 42:	learn: 9261.9164474	total: 92.1ms	remaining: 379ms
# 43:	learn: 9209.2882097	total: 93.7ms	remaining: 375ms
# 44:	learn: 9154.2834863	total: 95.4ms	remaining: 371ms
# 45:	learn: 9101.3514262	total: 96.6ms	remaining: 365ms
# 46:	learn: 9048.8456287	total: 97.6ms	remaining: 359ms
# 47:	learn: 8991.7111649	total: 98.7ms	remaining: 354ms
# 48:	learn: 8940.2805339	total: 99.8ms	remaining: 348ms
# 49:	learn: 8887.5180736	total: 102ms	remaining: 346ms
# 50:	learn: 8834.8983106	total: 103ms	remaining: 342ms
# 51:	learn: 8782.9533127	total: 105ms	remaining: 338ms
# 52:	learn: 8727.5991636	total: 106ms	remaining: 333ms
# 53:	learn: 8676.7548068	total: 107ms	remaining: 330ms
# 54:	learn: 8621.0155859	total: 109ms	remaining: 327ms
# 55:	learn: 8570.0333120	total: 110ms	remaining: 323ms
# 56:	learn: 8521.5307318	total: 112ms	remaining: 319ms
# 57:	learn: 8475.3522966	total: 113ms	remaining: 316ms
# 58:	learn: 8429.5624709	total: 114ms	remaining: 312ms
# 59:	learn: 8383.5459244	total: 116ms	remaining: 308ms
# 60:	learn: 8335.5536329	total: 117ms	remaining: 306ms
# 61:	learn: 8289.9963926	total: 119ms	remaining: 302ms
# 62:	learn: 8246.4273903	total: 120ms	remaining: 298ms
# 63:	learn: 8202.9212671	total: 121ms	remaining: 295ms
# 64:	learn: 8158.7433439	total: 123ms	remaining: 293ms
# 65:	learn: 8112.2642785	total: 124ms	remaining: 290ms
# 66:	learn: 8066.7444164	total: 126ms	remaining: 287ms
# 67:	learn: 8021.8749014	total: 127ms	remaining: 285ms
# 68:	learn: 7977.1734010	total: 129ms	remaining: 282ms
# 69:	learn: 7932.6894679	total: 131ms	remaining: 280ms
# 70:	learn: 7888.3579007	total: 132ms	remaining: 278ms
# 71:	learn: 7848.7601952	total: 137ms	remaining: 281ms
# 72:	learn: 7808.3133560	total: 138ms	remaining: 278ms
# 73:	learn: 7769.5307285	total: 139ms	remaining: 274ms
# 74:	learn: 7725.8158304	total: 145ms	remaining: 280ms
# 75:	learn: 7686.5347001	total: 146ms	remaining: 277ms
# 76:	learn: 7650.8279589	total: 154ms	remaining: 287ms
# 77:	learn: 7614.5380546	total: 155ms	remaining: 283ms
# 78:	learn: 7576.0491136	total: 156ms	remaining: 279ms
# 79:	learn: 7533.6784705	total: 157ms	remaining: 275ms
# 80:	learn: 7491.8451163	total: 158ms	remaining: 271ms
# 81:	learn: 7452.1956539	total: 159ms	remaining: 267ms
# 82:	learn: 7415.5115811	total: 159ms	remaining: 263ms
# 83:	learn: 7378.0005348	total: 161ms	remaining: 260ms
# 84:	learn: 7338.2953770	total: 162ms	remaining: 258ms
# 85:	learn: 7297.1497545	total: 164ms	remaining: 256ms
# 86:	learn: 7259.1015686	total: 166ms	remaining: 253ms
# 87:	learn: 7225.8717360	total: 167ms	remaining: 250ms
# 88:	learn: 7191.5714231	total: 168ms	remaining: 247ms
# 89:	learn: 7156.8485199	total: 170ms	remaining: 245ms
# 90:	learn: 7122.5052349	total: 171ms	remaining: 242ms
# 91:	learn: 7084.8898985	total: 172ms	remaining: 239ms
# 92:	learn: 7049.3997253	total: 173ms	remaining: 237ms
# 93:	learn: 7012.9289073	total: 175ms	remaining: 235ms
# 94:	learn: 6982.0868463	total: 177ms	remaining: 233ms
# 95:	learn: 6948.4012180	total: 179ms	remaining: 231ms
# 96:	learn: 6917.9798258	total: 188ms	remaining: 238ms
# 97:	learn: 6881.8269065	total: 190ms	remaining: 237ms
# 98:	learn: 6848.3555697	total: 192ms	remaining: 235ms
# 99:	learn: 6817.9900907	total: 194ms	remaining: 233ms
# 100:	learn: 6782.9319876	total: 196ms	remaining: 230ms
# 101:	learn: 6752.4962772	total: 197ms	remaining: 228ms
# 102:	learn: 6720.5554436	total: 199ms	remaining: 226ms
# 103:	learn: 6690.9210794	total: 200ms	remaining: 223ms
# 104:	learn: 6659.8572863	total: 201ms	remaining: 221ms
# 105:	learn: 6631.4680477	total: 203ms	remaining: 219ms
# 106:	learn: 6602.3901026	total: 205ms	remaining: 216ms
# 107:	learn: 6569.8063158	total: 207ms	remaining: 215ms
# 108:	learn: 6540.9931451	total: 213ms	remaining: 216ms
# 109:	learn: 6513.1301645	total: 214ms	remaining: 214ms
# 110:	learn: 6484.2160034	total: 216ms	remaining: 213ms
# 111:	learn: 6459.8282167	total: 218ms	remaining: 210ms
# 112:	learn: 6434.0699939	total: 219ms	remaining: 208ms
# 113:	learn: 6406.8034114	total: 221ms	remaining: 205ms
# 114:	learn: 6379.3118058	total: 222ms	remaining: 203ms
# 115:	learn: 6353.2455699	total: 224ms	remaining: 201ms
# 116:	learn: 6323.3144053	total: 226ms	remaining: 199ms
# 117:	learn: 6294.1555201	total: 227ms	remaining: 196ms
# 118:	learn: 6267.0511035	total: 237ms	remaining: 201ms
# 119:	learn: 6241.0250394	total: 253ms	remaining: 211ms
# 120:	learn: 6217.2800653	total: 258ms	remaining: 211ms
# 121:	learn: 6195.6986111	total: 259ms	remaining: 208ms
# 122:	learn: 6173.9864208	total: 261ms	remaining: 206ms
# 123:	learn: 6147.1701244	total: 262ms	remaining: 203ms
# 124:	learn: 6121.5869746	total: 264ms	remaining: 201ms
# 125:	learn: 6096.8829701	total: 266ms	remaining: 198ms
# 126:	learn: 6076.3536751	total: 268ms	remaining: 196ms
# 127:	learn: 6054.4523282	total: 269ms	remaining: 193ms
# 128:	learn: 6033.6390515	total: 271ms	remaining: 191ms
# 129:	learn: 6012.1953588	total: 272ms	remaining: 188ms
# 130:	learn: 5991.2499842	total: 278ms	remaining: 189ms
# 131:	learn: 5970.5307579	total: 279ms	remaining: 186ms
# 132:	learn: 5948.6934347	total: 281ms	remaining: 184ms
# 133:	learn: 5925.2970644	total: 283ms	remaining: 181ms
# 134:	learn: 5903.1365599	total: 284ms	remaining: 179ms
# 135:	learn: 5883.9449611	total: 286ms	remaining: 176ms
# 136:	learn: 5861.7733918	total: 287ms	remaining: 174ms
# 137:	learn: 5843.7806137	total: 289ms	remaining: 172ms
# 138:	learn: 5824.0830127	total: 291ms	remaining: 170ms
# 139:	learn: 5805.1591933	total: 293ms	remaining: 167ms
# 140:	learn: 5783.3145359	total: 295ms	remaining: 165ms
# 141:	learn: 5763.5793683	total: 296ms	remaining: 163ms
# 142:	learn: 5744.9301496	total: 298ms	remaining: 161ms
# 143:	learn: 5726.7521707	total: 299ms	remaining: 158ms
# 144:	learn: 5707.2889257	total: 300ms	remaining: 155ms
# 145:	learn: 5690.0004038	total: 302ms	remaining: 153ms
# 146:	learn: 5669.9129584	total: 303ms	remaining: 151ms
# 147:	learn: 5653.3176524	total: 308ms	remaining: 150ms
# 148:	learn: 5635.4335671	total: 309ms	remaining: 147ms
# 149:	learn: 5619.7632577	total: 311ms	remaining: 145ms
# 150:	learn: 5601.5367077	total: 312ms	remaining: 142ms
# 151:	learn: 5584.1112445	total: 313ms	remaining: 140ms
# 152:	learn: 5566.3867603	total: 315ms	remaining: 138ms
# 153:	learn: 5551.2461300	total: 316ms	remaining: 136ms
# 154:	learn: 5539.0836204	total: 317ms	remaining: 133ms
# 155:	learn: 5523.2803558	total: 319ms	remaining: 131ms
# 156:	learn: 5509.0300153	total: 323ms	remaining: 130ms
# 157:	learn: 5491.9886024	total: 325ms	remaining: 128ms
# 158:	learn: 5476.1861699	total: 327ms	remaining: 125ms
# 159:	learn: 5462.7935435	total: 328ms	remaining: 123ms
# 160:	learn: 5445.6795143	total: 330ms	remaining: 121ms
# 161:	learn: 5429.4523206	total: 332ms	remaining: 119ms
# 162:	learn: 5413.9839895	total: 333ms	remaining: 117ms
# 163:	learn: 5399.7789453	total: 335ms	remaining: 114ms
# 164:	learn: 5386.3990960	total: 336ms	remaining: 112ms
# 165:	learn: 5372.8203123	total: 337ms	remaining: 110ms
# 166:	learn: 5358.6961402	total: 338ms	remaining: 107ms
# 167:	learn: 5343.5645229	total: 339ms	remaining: 105ms
# 168:	learn: 5328.2040061	total: 341ms	remaining: 103ms
# 169:	learn: 5313.9253425	total: 342ms	remaining: 101ms
# 170:	learn: 5300.2001743	total: 344ms	remaining: 98.6ms
# 171:	learn: 5285.4276821	total: 346ms	remaining: 96.5ms
# 172:	learn: 5273.4213106	total: 348ms	remaining: 94.4ms
# 173:	learn: 5260.1737501	total: 349ms	remaining: 92.2ms
# 174:	learn: 5245.9981794	total: 350ms	remaining: 90.1ms
# 175:	learn: 5233.0126926	total: 352ms	remaining: 87.9ms
# 176:	learn: 5220.0780596	total: 353ms	remaining: 85.8ms
# 177:	learn: 5205.2218355	total: 355ms	remaining: 83.8ms
# 178:	learn: 5192.3343255	total: 356ms	remaining: 81.7ms
# 179:	learn: 5180.1951146	total: 357ms	remaining: 79.4ms
# 180:	learn: 5168.3232686	total: 358ms	remaining: 77.2ms
# 181:	learn: 5156.5070441	total: 363ms	remaining: 75.7ms
# 182:	learn: 5142.8276760	total: 364ms	remaining: 73.6ms
# 183:	learn: 5129.4979936	total: 366ms	remaining: 71.5ms
# 184:	learn: 5117.8592940	total: 367ms	remaining: 69.5ms
# 185:	learn: 5106.1722532	total: 369ms	remaining: 67.4ms
# 186:	learn: 5094.1571225	total: 371ms	remaining: 65.4ms
# 187:	learn: 5083.4039703	total: 372ms	remaining: 63.3ms
# 188:	learn: 5072.9438717	total: 374ms	remaining: 61.3ms
# 189:	learn: 5062.0572198	total: 376ms	remaining: 59.3ms
# 190:	learn: 5051.9142605	total: 377ms	remaining: 57.3ms
# 191:	learn: 5042.2352179	total: 379ms	remaining: 55.3ms
# 192:	learn: 5031.5768340	total: 381ms	remaining: 53.2ms
# 193:	learn: 5019.8580418	total: 382ms	remaining: 51.2ms
# 194:	learn: 5009.7299876	total: 386ms	remaining: 49.5ms
# 195:	learn: 4998.5726782	total: 401ms	remaining: 49.1ms
# 196:	learn: 4987.8050601	total: 405ms	remaining: 47.3ms
# 197:	learn: 4978.4320489	total: 415ms	remaining: 46.1ms
# 198:	learn: 4968.6279900	total: 416ms	remaining: 43.9ms
# 199:	learn: 4959.8957658	total: 417ms	remaining: 41.7ms
# 200:	learn: 4949.2709788	total: 418ms	remaining: 39.5ms
# 201:	learn: 4941.3701551	total: 419ms	remaining: 37.3ms
# 202:	learn: 4931.4294798	total: 420ms	remaining: 35.1ms
# 203:	learn: 4922.9434264	total: 421ms	remaining: 33ms
# 204:	learn: 4912.6896834	total: 422ms	remaining: 30.9ms
# 205:	learn: 4903.2951166	total: 423ms	remaining: 28.7ms
# 206:	learn: 4895.9696390	total: 423ms	remaining: 26.6ms
# 207:	learn: 4887.9275317	total: 424ms	remaining: 24.4ms
# 208:	learn: 4880.2140855	total: 425ms	remaining: 22.3ms
# 209:	learn: 4871.8091785	total: 425ms	remaining: 20.3ms
# 210:	learn: 4863.1379278	total: 435ms	remaining: 18.6ms
# 211:	learn: 4853.9542158	total: 436ms	remaining: 16.5ms
# 212:	learn: 4845.4807708	total: 437ms	remaining: 14.4ms
# 213:	learn: 4837.0039062	total: 445ms	remaining: 12.5ms
# 214:	learn: 4828.7443605	total: 446ms	remaining: 10.4ms
# 215:	learn: 4820.7613334	total: 448ms	remaining: 8.3ms
# 216:	learn: 4810.8631241	total: 450ms	remaining: 6.22ms
# 217:	learn: 4803.6033384	total: 452ms	remaining: 4.14ms
# 218:	learn: 4794.9297522	total: 454ms	remaining: 2.07ms
# 219:	learn: 4788.1978220	total: 455ms	remaining: 0us
# [CV] END ..learning_rate=0.01, max_depth=6, n_estimators=220; total time=   0.7s
# 0:	learn: 12330.8683004	total: 10.4ms	remaining: 2.29s
# 1:	learn: 12251.2747242	total: 14.7ms	remaining: 1.6s
# 2:	learn: 12162.4349857	total: 24.7ms	remaining: 1.79s
# 3:	learn: 12071.4305229	total: 27.8ms	remaining: 1.5s
# 4:	learn: 11988.1249769	total: 29.5ms	remaining: 1.27s
# 5:	learn: 11906.3851882	total: 31.3ms	remaining: 1.12s
# 6:	learn: 11825.7478705	total: 33.2ms	remaining: 1.01s
# 7:	learn: 11747.7545651	total: 35.2ms	remaining: 933ms
# 8:	learn: 11664.3309680	total: 50.2ms	remaining: 1.18s
# 9:	learn: 11585.4846914	total: 51.4ms	remaining: 1.08s
# 10:	learn: 11504.2195726	total: 52.5ms	remaining: 998ms
# 11:	learn: 11423.4534948	total: 53.4ms	remaining: 926ms
# 12:	learn: 11348.2100764	total: 55.1ms	remaining: 877ms
# 13:	learn: 11268.8246410	total: 57.1ms	remaining: 841ms
# 14:	learn: 11188.6745229	total: 59.2ms	remaining: 809ms
# 15:	learn: 11113.2822662	total: 61ms	remaining: 778ms
# 16:	learn: 11038.8744746	total: 62.8ms	remaining: 750ms
# 17:	learn: 10963.2717137	total: 64.5ms	remaining: 724ms
# 18:	learn: 10892.1404570	total: 66.4ms	remaining: 702ms
# 19:	learn: 10817.7222139	total: 68.4ms	remaining: 684ms
# 20:	learn: 10743.1617582	total: 70.1ms	remaining: 664ms
# 21:	learn: 10673.0266502	total: 71.7ms	remaining: 646ms
# 22:	learn: 10610.6193858	total: 73.7ms	remaining: 632ms
# 23:	learn: 10546.0668307	total: 75.7ms	remaining: 618ms
# 24:	learn: 10475.0544965	total: 77.2ms	remaining: 602ms
# 25:	learn: 10418.1504653	total: 78.7ms	remaining: 587ms
# 26:	learn: 10354.4494511	total: 80.7ms	remaining: 577ms
# 27:	learn: 10289.3232533	total: 82.7ms	remaining: 567ms
# 28:	learn: 10231.0162237	total: 84.8ms	remaining: 559ms
# 29:	learn: 10173.1413693	total: 86.8ms	remaining: 550ms
# 30:	learn: 10107.3005219	total: 88.8ms	remaining: 542ms
# 31:	learn: 10043.0449569	total: 90.9ms	remaining: 534ms
# 32:	learn: 9972.4057793	total: 92.4ms	remaining: 524ms
# 33:	learn: 9908.0484413	total: 94ms	remaining: 514ms
# 34:	learn: 9844.6328065	total: 95.5ms	remaining: 505ms
# 35:	learn: 9785.1374550	total: 96.5ms	remaining: 493ms
# 36:	learn: 9721.6220081	total: 98.2ms	remaining: 486ms
# 37:	learn: 9661.9169093	total: 99.9ms	remaining: 478ms
# 38:	learn: 9597.9563020	total: 105ms	remaining: 486ms
# 39:	learn: 9542.5408190	total: 105ms	remaining: 475ms
# 40:	learn: 9481.3132691	total: 106ms	remaining: 464ms
# 41:	learn: 9426.4334346	total: 108ms	remaining: 458ms
# 42:	learn: 9375.3545680	total: 110ms	remaining: 452ms
# 43:	learn: 9320.1432175	total: 111ms	remaining: 444ms
# 44:	learn: 9257.5241108	total: 112ms	remaining: 437ms
# 45:	learn: 9203.2057395	total: 114ms	remaining: 432ms
# 46:	learn: 9146.1761095	total: 115ms	remaining: 425ms
# 47:	learn: 9090.7236134	total: 116ms	remaining: 416ms
# 48:	learn: 9037.2591019	total: 118ms	remaining: 411ms
# 49:	learn: 8984.4969998	total: 119ms	remaining: 405ms
# 50:	learn: 8926.9662919	total: 120ms	remaining: 399ms
# 51:	learn: 8881.7347969	total: 121ms	remaining: 391ms
# 52:	learn: 8826.3783696	total: 122ms	remaining: 385ms
# 53:	learn: 8773.1324315	total: 124ms	remaining: 381ms
# 54:	learn: 8723.6315429	total: 126ms	remaining: 377ms
# 55:	learn: 8675.6786955	total: 127ms	remaining: 372ms
# 56:	learn: 8629.6913275	total: 130ms	remaining: 371ms
# 57:	learn: 8583.3381959	total: 130ms	remaining: 364ms
# 58:	learn: 8531.0597445	total: 132ms	remaining: 360ms
# 59:	learn: 8480.9992006	total: 133ms	remaining: 356ms
# 60:	learn: 8428.5260630	total: 134ms	remaining: 350ms
# 61:	learn: 8384.6132826	total: 136ms	remaining: 348ms
# 62:	learn: 8337.1801211	total: 138ms	remaining: 345ms
# 63:	learn: 8285.8893241	total: 139ms	remaining: 339ms
# 64:	learn: 8242.4870708	total: 141ms	remaining: 335ms
# 65:	learn: 8197.2646292	total: 142ms	remaining: 332ms
# 66:	learn: 8152.1438197	total: 144ms	remaining: 329ms
# 67:	learn: 8105.0649163	total: 146ms	remaining: 326ms
# 68:	learn: 8056.2776436	total: 147ms	remaining: 323ms
# 69:	learn: 8014.7617538	total: 149ms	remaining: 319ms
# 70:	learn: 7972.2075349	total: 151ms	remaining: 316ms
# 71:	learn: 7934.0385612	total: 152ms	remaining: 313ms
# 72:	learn: 7894.0267052	total: 153ms	remaining: 309ms
# 73:	learn: 7851.2272647	total: 155ms	remaining: 305ms
# 74:	learn: 7808.6381258	total: 156ms	remaining: 303ms
# 75:	learn: 7765.8597514	total: 158ms	remaining: 300ms
# 76:	learn: 7728.6208977	total: 159ms	remaining: 296ms
# 77:	learn: 7687.3311299	total: 161ms	remaining: 293ms
# 78:	learn: 7648.4604313	total: 163ms	remaining: 291ms
# 79:	learn: 7609.8874254	total: 164ms	remaining: 288ms
# 80:	learn: 7575.0099900	total: 166ms	remaining: 285ms
# 81:	learn: 7534.4114823	total: 168ms	remaining: 282ms
# 82:	learn: 7500.9186602	total: 169ms	remaining: 279ms
# 83:	learn: 7460.5220984	total: 171ms	remaining: 277ms
# 84:	learn: 7429.5682029	total: 174ms	remaining: 277ms
# 85:	learn: 7389.3002228	total: 178ms	remaining: 277ms
# 86:	learn: 7354.8866828	total: 180ms	remaining: 274ms
# 87:	learn: 7317.1712598	total: 181ms	remaining: 272ms
# 88:	learn: 7281.3837826	total: 191ms	remaining: 282ms
# 89:	learn: 7245.4007458	total: 197ms	remaining: 284ms
# 90:	learn: 7209.3404903	total: 198ms	remaining: 281ms
# 91:	learn: 7174.1408000	total: 200ms	remaining: 278ms
# 92:	learn: 7142.0089952	total: 202ms	remaining: 275ms
# 93:	learn: 7107.5011735	total: 203ms	remaining: 273ms
# 94:	learn: 7076.3363271	total: 205ms	remaining: 270ms
# 95:	learn: 7039.0698133	total: 207ms	remaining: 267ms
# 96:	learn: 7004.6303205	total: 208ms	remaining: 264ms
# 97:	learn: 6973.5223012	total: 210ms	remaining: 261ms
# 98:	learn: 6937.7110000	total: 212ms	remaining: 259ms
# 99:	learn: 6909.4592336	total: 214ms	remaining: 256ms
# 100:	learn: 6877.7871786	total: 215ms	remaining: 254ms
# 101:	learn: 6843.7499211	total: 217ms	remaining: 251ms
# 102:	learn: 6810.9044273	total: 218ms	remaining: 248ms
# 103:	learn: 6781.0212961	total: 220ms	remaining: 245ms
# 104:	learn: 6752.2902366	total: 222ms	remaining: 243ms
# 105:	learn: 6718.4664132	total: 223ms	remaining: 240ms
# 106:	learn: 6689.4048884	total: 224ms	remaining: 236ms
# 107:	learn: 6660.3818241	total: 226ms	remaining: 234ms
# 108:	learn: 6630.2027241	total: 227ms	remaining: 231ms
# 109:	learn: 6604.3713716	total: 229ms	remaining: 229ms
# 110:	learn: 6578.5402725	total: 230ms	remaining: 226ms
# 111:	learn: 6551.4769433	total: 232ms	remaining: 224ms
# 112:	learn: 6523.9695246	total: 234ms	remaining: 221ms
# 113:	learn: 6496.6063099	total: 235ms	remaining: 219ms
# 114:	learn: 6465.9106468	total: 237ms	remaining: 216ms
# 115:	learn: 6436.0435616	total: 238ms	remaining: 213ms
# 116:	learn: 6410.4107622	total: 240ms	remaining: 211ms
# 117:	learn: 6382.6099168	total: 242ms	remaining: 209ms
# 118:	learn: 6358.2795420	total: 243ms	remaining: 206ms
# 119:	learn: 6332.8195010	total: 244ms	remaining: 203ms
# 120:	learn: 6308.9097751	total: 246ms	remaining: 201ms
# 121:	learn: 6281.3494654	total: 247ms	remaining: 199ms
# 122:	learn: 6254.5809042	total: 249ms	remaining: 196ms
# 123:	learn: 6230.7301582	total: 250ms	remaining: 194ms
# 124:	learn: 6207.0628626	total: 252ms	remaining: 191ms
# 125:	learn: 6183.6661762	total: 253ms	remaining: 189ms
# 126:	learn: 6162.9134120	total: 255ms	remaining: 187ms
# 127:	learn: 6142.4104969	total: 257ms	remaining: 184ms
# 128:	learn: 6120.2670886	total: 258ms	remaining: 182ms
# 129:	learn: 6098.5076820	total: 260ms	remaining: 180ms
# 130:	learn: 6074.8882459	total: 262ms	remaining: 178ms
# 131:	learn: 6051.6158402	total: 263ms	remaining: 176ms
# 132:	learn: 6028.9921025	total: 265ms	remaining: 173ms
# 133:	learn: 6008.5430457	total: 266ms	remaining: 171ms
# 134:	learn: 5985.9805766	total: 268ms	remaining: 169ms
# 135:	learn: 5965.5752050	total: 270ms	remaining: 167ms
# 136:	learn: 5944.9222108	total: 271ms	remaining: 164ms
# 137:	learn: 5925.6870736	total: 273ms	remaining: 162ms
# 138:	learn: 5904.9285707	total: 274ms	remaining: 160ms
# 139:	learn: 5886.9712233	total: 275ms	remaining: 157ms
# 140:	learn: 5867.5841988	total: 277ms	remaining: 155ms
# 141:	learn: 5849.8444170	total: 278ms	remaining: 153ms
# 142:	learn: 5832.8777843	total: 279ms	remaining: 150ms
# 143:	learn: 5815.8468471	total: 281ms	remaining: 148ms
# 144:	learn: 5795.9820900	total: 282ms	remaining: 146ms
# 145:	learn: 5778.8112913	total: 284ms	remaining: 144ms
# 146:	learn: 5759.8385469	total: 286ms	remaining: 142ms
# 147:	learn: 5741.5282435	total: 287ms	remaining: 140ms
# 148:	learn: 5722.8818439	total: 289ms	remaining: 138ms
# 149:	learn: 5704.4003315	total: 290ms	remaining: 135ms
# 150:	learn: 5686.5698837	total: 292ms	remaining: 133ms
# 151:	learn: 5671.3095178	total: 293ms	remaining: 131ms
# 152:	learn: 5658.3727753	total: 294ms	remaining: 129ms
# 153:	learn: 5643.2912696	total: 295ms	remaining: 127ms
# 154:	learn: 5628.1393989	total: 297ms	remaining: 125ms
# 155:	learn: 5611.6761663	total: 299ms	remaining: 122ms
# 156:	learn: 5595.4637429	total: 300ms	remaining: 121ms
# 157:	learn: 5581.3033895	total: 303ms	remaining: 119ms
# 158:	learn: 5564.2242686	total: 304ms	remaining: 117ms
# 159:	learn: 5548.0281507	total: 305ms	remaining: 115ms
# 160:	learn: 5533.3121612	total: 307ms	remaining: 113ms
# 161:	learn: 5519.0564211	total: 309ms	remaining: 111ms
# 162:	learn: 5504.8208883	total: 310ms	remaining: 109ms
# 163:	learn: 5489.7265488	total: 311ms	remaining: 106ms
# 164:	learn: 5476.8135758	total: 312ms	remaining: 104ms
# 165:	learn: 5462.2383386	total: 313ms	remaining: 102ms
# 166:	learn: 5447.5721106	total: 315ms	remaining: 100ms
# 167:	learn: 5435.3663555	total: 317ms	remaining: 98ms
# 168:	learn: 5421.8214033	total: 318ms	remaining: 96ms
# 169:	learn: 5406.7522650	total: 320ms	remaining: 94ms
# 170:	learn: 5391.4281674	total: 321ms	remaining: 92ms
# 171:	learn: 5378.0463170	total: 323ms	remaining: 90ms
# 172:	learn: 5364.8779120	total: 324ms	remaining: 88ms
# 173:	learn: 5352.2812776	total: 326ms	remaining: 86.1ms
# 174:	learn: 5339.9294639	total: 327ms	remaining: 84.2ms
# 175:	learn: 5328.8410893	total: 329ms	remaining: 82.2ms
# 176:	learn: 5316.6934390	total: 330ms	remaining: 80.2ms
# 177:	learn: 5302.7265220	total: 332ms	remaining: 78.3ms
# 178:	learn: 5289.9314213	total: 333ms	remaining: 76.3ms
# 179:	learn: 5278.4600303	total: 334ms	remaining: 74.3ms
# 180:	learn: 5268.1625323	total: 336ms	remaining: 72.4ms
# 181:	learn: 5254.9068614	total: 337ms	remaining: 70.4ms
# 182:	learn: 5242.6223318	total: 339ms	remaining: 68.5ms
# 183:	learn: 5230.2019539	total: 341ms	remaining: 66.6ms
# 184:	learn: 5218.4181662	total: 342ms	remaining: 64.8ms
# 185:	learn: 5210.2785542	total: 344ms	remaining: 62.8ms
# 186:	learn: 5199.3323607	total: 345ms	remaining: 60.8ms
# 187:	learn: 5186.8790845	total: 347ms	remaining: 59ms
# 188:	learn: 5176.1587496	total: 352ms	remaining: 57.7ms
# 189:	learn: 5166.1049784	total: 356ms	remaining: 56.2ms
# 190:	learn: 5153.3481768	total: 360ms	remaining: 54.7ms
# 191:	learn: 5141.8903293	total: 364ms	remaining: 53.1ms
# 192:	learn: 5132.2186273	total: 367ms	remaining: 51.4ms
# 193:	learn: 5121.2926395	total: 370ms	remaining: 49.5ms
# ...
# 60:	learn: 4257.4572579	total: 31.4ms	remaining: 83.3ms
# 61:	learn: 4250.4713849	total: 32ms	remaining: 83ms
# 62:	learn: 4247.3681997	total: 32.5ms	remaining: 82.5ms
# 63:	learn: 4241.8730363	total: 35.5ms	remaining: 88.2ms
# 64:	learn: 4237.0086513	total: 36.6ms	remaining: 88.9ms
# 65:	learn: 4229.0152755	total: 41.6ms	remaining: 99ms
# 66:	learn: 4221.6097380	total: 42.2ms	remaining: 98.3ms
# 67:	learn: 4216.2921710	total: 42.7ms	remaining: 97.4ms
# 68:	learn: 4209.7566058	total: 43.3ms	remaining: 96.5ms
# 69:	learn: 4202.9212300	total: 44.4ms	remaining: 97ms
# 70:	learn: 4198.2929870	total: 45ms	remaining: 96.2ms
# 71:	learn: 4189.6268924	total: 45.5ms	remaining: 95.5ms
# 72:	learn: 4186.8351564	total: 45.9ms	remaining: 94.4ms
# 73:	learn: 4179.2536889	total: 46.5ms	remaining: 93.6ms
# 74:	learn: 4170.0856115	total: 47ms	remaining: 92.8ms
# 75:	learn: 4165.9691808	total: 47.5ms	remaining: 91.9ms
# 76:	learn: 4160.6206810	total: 48ms	remaining: 91.1ms
# 77:	learn: 4156.2321396	total: 48.6ms	remaining: 90.3ms
# 78:	learn: 4148.1105121	total: 49.1ms	remaining: 89.5ms
# 79:	learn: 4140.9766288	total: 49.6ms	remaining: 88.7ms
# 80:	learn: 4133.0730038	total: 50.1ms	remaining: 87.9ms
# 81:	learn: 4128.7583273	total: 50.7ms	remaining: 87.1ms
# 82:	learn: 4124.7729992	total: 51.2ms	remaining: 86.3ms
# 83:	learn: 4117.9401067	total: 51.8ms	remaining: 85.7ms
# 84:	learn: 4113.1428564	total: 52.3ms	remaining: 85ms
# 85:	learn: 4110.8841233	total: 52.9ms	remaining: 84.2ms
# 86:	learn: 4098.1841372	total: 53.4ms	remaining: 83.6ms
# 87:	learn: 4090.8884507	total: 54ms	remaining: 82.9ms
# 88:	learn: 4087.7549592	total: 54.6ms	remaining: 82.2ms
# 89:	learn: 4085.0789878	total: 55.2ms	remaining: 81.6ms
# 90:	learn: 4080.2964314	total: 55.8ms	remaining: 80.9ms
# 91:	learn: 4074.6772662	total: 56.3ms	remaining: 80.2ms
# 92:	learn: 4068.6162106	total: 57ms	remaining: 79.6ms
# 93:	learn: 4060.5895621	total: 57.5ms	remaining: 79ms
# 94:	learn: 4057.3918319	total: 58.1ms	remaining: 78.3ms
# 95:	learn: 4053.2203285	total: 58.7ms	remaining: 77.6ms
# 96:	learn: 4044.5323417	total: 59.2ms	remaining: 76.9ms
# 97:	learn: 4041.7558041	total: 59.7ms	remaining: 76.1ms
# 98:	learn: 4036.2947844	total: 60.3ms	remaining: 75.5ms
# 99:	learn: 4033.7361514	total: 60.9ms	remaining: 74.9ms
# 100:	learn: 4025.0027283	total: 61.4ms	remaining: 74.2ms
# 101:	learn: 4023.1650108	total: 61.8ms	remaining: 73.3ms
# 102:	learn: 4016.4754350	total: 62.3ms	remaining: 72.6ms
# 103:	learn: 4013.3113286	total: 62.8ms	remaining: 71.9ms
# 104:	learn: 4008.0973874	total: 63.3ms	remaining: 71.1ms
# 105:	learn: 4005.1923316	total: 63.8ms	remaining: 70.4ms
# 106:	learn: 4003.8653995	total: 64ms	remaining: 69.4ms
# 107:	learn: 3995.1774012	total: 64.5ms	remaining: 68.7ms
# 108:	learn: 3992.6077023	total: 65ms	remaining: 68ms
# 109:	learn: 3987.7411295	total: 65.5ms	remaining: 67.3ms
# 110:	learn: 3983.2471886	total: 66ms	remaining: 66.6ms
# 111:	learn: 3971.0927463	total: 66.4ms	remaining: 65.8ms
# 112:	learn: 3961.5835102	total: 66.9ms	remaining: 65.2ms
# 113:	learn: 3960.1946091	total: 67.5ms	remaining: 64.5ms
# 114:	learn: 3958.4405819	total: 67.9ms	remaining: 63.8ms
# 115:	learn: 3954.1417979	total: 68.4ms	remaining: 63.1ms
# 116:	learn: 3949.7163378	total: 68.9ms	remaining: 62.5ms
# 117:	learn: 3945.6050971	total: 69.5ms	remaining: 61.9ms
# 118:	learn: 3941.5995246	total: 70.1ms	remaining: 61.3ms
# 119:	learn: 3937.7411187	total: 70.7ms	remaining: 60.7ms
# 120:	learn: 3935.6214535	total: 71.3ms	remaining: 60.1ms
# 121:	learn: 3926.6794574	total: 71.9ms	remaining: 59.5ms
# 122:	learn: 3923.6109432	total: 72.4ms	remaining: 58.8ms
# 123:	learn: 3920.0377572	total: 72.9ms	remaining: 58.2ms
# 124:	learn: 3915.5985475	total: 73.3ms	remaining: 57.5ms
# 125:	learn: 3913.9845792	total: 73.8ms	remaining: 56.8ms
# 126:	learn: 3910.8374119	total: 74.3ms	remaining: 56.2ms
# 127:	learn: 3904.8651556	total: 74.8ms	remaining: 55.5ms
# 128:	learn: 3901.4950282	total: 75.3ms	remaining: 54.8ms
# 129:	learn: 3898.0387734	total: 75.8ms	remaining: 54.2ms
# 130:	learn: 3891.4902617	total: 76.2ms	remaining: 53.5ms
# 131:	learn: 3883.0493104	total: 76.8ms	remaining: 52.9ms
# 132:	learn: 3879.9707800	total: 77.3ms	remaining: 52.3ms
# 133:	learn: 3876.0824106	total: 77.8ms	remaining: 51.7ms
# 134:	learn: 3873.1207910	total: 78.3ms	remaining: 51ms
# 135:	learn: 3869.2304855	total: 78.8ms	remaining: 50.4ms
# 136:	learn: 3867.5445282	total: 79.3ms	remaining: 49.8ms
# 137:	learn: 3865.1689044	total: 79.8ms	remaining: 49.2ms
# 138:	learn: 3862.4253280	total: 80.3ms	remaining: 48.5ms
# 139:	learn: 3858.1772935	total: 81ms	remaining: 48ms
# 140:	learn: 3857.1246244	total: 81.6ms	remaining: 47.4ms
# 141:	learn: 3854.5610958	total: 82.2ms	remaining: 46.9ms
# 142:	learn: 3849.5892870	total: 82.8ms	remaining: 46.3ms
# 143:	learn: 3847.4217055	total: 83.4ms	remaining: 45.7ms
# 144:	learn: 3847.1391755	total: 83.9ms	remaining: 45.1ms
# 145:	learn: 3844.8081627	total: 84.4ms	remaining: 44.5ms
# 146:	learn: 3835.3902322	total: 84.9ms	remaining: 43.9ms
# 147:	learn: 3834.1591673	total: 85.4ms	remaining: 43.3ms
# 148:	learn: 3831.2046999	total: 85.9ms	remaining: 42.7ms
# 149:	learn: 3824.1315921	total: 86.4ms	remaining: 42.1ms
# 150:	learn: 3821.6958949	total: 87ms	remaining: 41.5ms
# 151:	learn: 3817.5603566	total: 87.5ms	remaining: 40.9ms
# 152:	learn: 3815.4718473	total: 88ms	remaining: 40.3ms
# 153:	learn: 3809.7753328	total: 88.5ms	remaining: 39.7ms
# 154:	learn: 3805.9944163	total: 89ms	remaining: 39ms
# 155:	learn: 3796.5245540	total: 89.5ms	remaining: 38.5ms
# 156:	learn: 3793.4026460	total: 90.1ms	remaining: 37.9ms
# 157:	learn: 3792.8400286	total: 90.6ms	remaining: 37.3ms
# 158:	learn: 3788.5284245	total: 91.1ms	remaining: 36.7ms
# 159:	learn: 3784.6317217	total: 91.7ms	remaining: 36.1ms
# 160:	learn: 3779.8020927	total: 92.2ms	remaining: 35.5ms
# 161:	learn: 3777.8034821	total: 92.7ms	remaining: 34.9ms
# 162:	learn: 3774.6524908	total: 93.3ms	remaining: 34.3ms
# 163:	learn: 3769.8579885	total: 93.9ms	remaining: 33.8ms
# 164:	learn: 3766.5679585	total: 104ms	remaining: 36.6ms
# 165:	learn: 3762.2793179	total: 105ms	remaining: 35.9ms
# 166:	learn: 3759.4429573	total: 110ms	remaining: 36.9ms
# 167:	learn: 3757.5742313	total: 111ms	remaining: 36.2ms
# 168:	learn: 3754.3005890	total: 111ms	remaining: 35.5ms
# 169:	learn: 3746.9567097	total: 112ms	remaining: 34.8ms
# 170:	learn: 3744.1874560	total: 112ms	remaining: 34.1ms
# 171:	learn: 3738.7959132	total: 113ms	remaining: 33.4ms
# 172:	learn: 3734.7869729	total: 113ms	remaining: 32.8ms
# 173:	learn: 3730.5658928	total: 114ms	remaining: 32.1ms
# 174:	learn: 3727.6373974	total: 115ms	remaining: 31.6ms
# 175:	learn: 3724.5781116	total: 116ms	remaining: 30.9ms
# 176:	learn: 3720.5166381	total: 116ms	remaining: 30.2ms
# 177:	learn: 3711.2182014	total: 117ms	remaining: 29.6ms
# 178:	learn: 3709.4218619	total: 117ms	remaining: 28.9ms
# 179:	learn: 3707.6167352	total: 118ms	remaining: 28.2ms
# 180:	learn: 3706.9546132	total: 118ms	remaining: 27.5ms
# 181:	learn: 3703.6317054	total: 119ms	remaining: 26.8ms
# 182:	learn: 3700.0949670	total: 119ms	remaining: 26.1ms
# 183:	learn: 3696.2559189	total: 120ms	remaining: 25.4ms
# 184:	learn: 3693.5780672	total: 121ms	remaining: 24.8ms
# 185:	learn: 3692.1085016	total: 121ms	remaining: 24.1ms
# 186:	learn: 3688.5047764	total: 122ms	remaining: 23.4ms
# 187:	learn: 3686.4982424	total: 135ms	remaining: 25ms
# 188:	learn: 3685.0951642	total: 135ms	remaining: 24.3ms
# 189:	learn: 3681.3571352	total: 136ms	remaining: 23.6ms
# 190:	learn: 3671.6899991	total: 136ms	remaining: 22.8ms
# 191:	learn: 3668.5107289	total: 137ms	remaining: 22.1ms
# 192:	learn: 3666.9457664	total: 137ms	remaining: 21.3ms
# 193:	learn: 3662.5309841	total: 138ms	remaining: 20.6ms
# 194:	learn: 3654.0220403	total: 143ms	remaining: 20.5ms
# 195:	learn: 3653.3220613	total: 144ms	remaining: 19.8ms
# 196:	learn: 3651.4196873	total: 144ms	remaining: 19ms
# 197:	learn: 3648.5113130	total: 145ms	remaining: 18.3ms
# 198:	learn: 3647.0706310	total: 145ms	remaining: 17.5ms
# 199:	learn: 3643.2933398	total: 146ms	remaining: 16.8ms
# 200:	learn: 3629.9166705	total: 147ms	remaining: 16ms
# 201:	learn: 3627.0893792	total: 147ms	remaining: 15.3ms
# 202:	learn: 3624.3154066	total: 148ms	remaining: 14.6ms
# 203:	learn: 3614.8158107	total: 148ms	remaining: 13.8ms
# 204:	learn: 3610.2200669	total: 149ms	remaining: 13.1ms
# 205:	learn: 3609.0125251	total: 149ms	remaining: 12.3ms
# 206:	learn: 3607.3488592	total: 150ms	remaining: 11.6ms
# 207:	learn: 3597.2992896	total: 151ms	remaining: 10.9ms
# 208:	learn: 3589.1346256	total: 151ms	remaining: 10.1ms
# 209:	learn: 3584.5516295	total: 152ms	remaining: 9.38ms
# 210:	learn: 3581.7912121	total: 152ms	remaining: 8.65ms
# 211:	learn: 3580.4572328	total: 153ms	remaining: 7.92ms
# 212:	learn: 3579.1806071	total: 153ms	remaining: 7.19ms
# 213:	learn: 3576.5158175	total: 154ms	remaining: 6.47ms
# 214:	learn: 3569.6896573	total: 154ms	remaining: 5.74ms
# 215:	learn: 3567.3697211	total: 155ms	remaining: 5.02ms
# 216:	learn: 3566.5680485	total: 162ms	remaining: 4.47ms
# 217:	learn: 3565.3427476	total: 162ms	remaining: 3.72ms
# 218:	learn: 3564.8541083	total: 163ms	remaining: 2.97ms
# 219:	learn: 3560.6194685	total: 170ms	remaining: 2.32ms
# 220:	learn: 3553.3132317	total: 170ms	remaining: 1.54ms
# 221:	learn: 3550.7936676	total: 175ms	remaining: 786us
# 222:	learn: 3549.6024166	total: 175ms	remaining: 0us
# [CV] END ..learning_rate=0.08, max_depth=5, n_estimators=223; total time=   0.3s
# 0:	learn: 11737.6134165	total: 602us	remaining: 59.6ms
# 1:	learn: 11252.9471814	total: 1.2ms	remaining: 58.6ms
# 2:	learn: 10764.9709906	total: 5.97ms	remaining: 193ms
# 3:	learn: 10296.6424829	total: 6.55ms	remaining: 157ms
# 4:	learn: 9888.0709548	total: 9.34ms	remaining: 178ms
# 5:	learn: 9469.7217074	total: 9.79ms	remaining: 153ms
# 6:	learn: 9094.1784450	total: 10.4ms	remaining: 138ms
# 7:	learn: 8721.1624352	total: 10.8ms	remaining: 124ms
# 8:	learn: 8400.8793215	total: 15.6ms	remaining: 157ms
# 9:	learn: 8111.3435985	total: 19.3ms	remaining: 174ms
# 10:	learn: 7813.2093463	total: 19.9ms	remaining: 161ms
# 11:	learn: 7552.9585179	total: 20.4ms	remaining: 150ms
# 12:	learn: 7310.1440743	total: 21ms	remaining: 140ms
# 13:	learn: 7099.2917742	total: 25.5ms	remaining: 157ms
# 14:	learn: 6896.0434387	total: 26.1ms	remaining: 148ms
# 15:	learn: 6708.8300762	total: 26.8ms	remaining: 141ms
# 16:	learn: 6515.7143441	total: 27.4ms	remaining: 134ms
# 17:	learn: 6387.5463745	total: 27.7ms	remaining: 126ms
# 18:	learn: 6224.0517089	total: 28.2ms	remaining: 120ms
# 19:	learn: 6082.2099525	total: 28.8ms	remaining: 115ms
# 20:	learn: 5956.6727252	total: 29.3ms	remaining: 110ms
# 21:	learn: 5830.6283644	total: 36.2ms	remaining: 129ms
# 22:	learn: 5729.5725433	total: 36.6ms	remaining: 122ms
# 23:	learn: 5620.6260807	total: 37.1ms	remaining: 118ms
# 24:	learn: 5513.7989396	total: 37.6ms	remaining: 113ms
# 25:	learn: 5417.3171357	total: 38.1ms	remaining: 109ms
# 26:	learn: 5330.5589147	total: 38.7ms	remaining: 105ms
# 27:	learn: 5258.1920683	total: 39.2ms	remaining: 101ms
# 28:	learn: 5182.0456438	total: 39.7ms	remaining: 97.3ms
# 29:	learn: 5119.7856591	total: 40.3ms	remaining: 93.9ms
# 30:	learn: 5057.6669421	total: 40.8ms	remaining: 90.8ms
# 31:	learn: 5004.5990335	total: 41.4ms	remaining: 88.1ms
# 32:	learn: 4956.2173602	total: 42.2ms	remaining: 85.6ms
# 33:	learn: 4916.6737843	total: 42.8ms	remaining: 83.1ms
# 34:	learn: 4876.5104348	total: 43.4ms	remaining: 80.7ms
# 35:	learn: 4838.4418365	total: 44.4ms	remaining: 78.9ms
# 36:	learn: 4794.1834555	total: 46ms	remaining: 78.3ms
# 37:	learn: 4764.8009637	total: 46.7ms	remaining: 76.1ms
# 38:	learn: 4728.3063843	total: 47.3ms	remaining: 73.9ms
# 39:	learn: 4700.8619810	total: 47.8ms	remaining: 71.7ms
# 40:	learn: 4675.5060597	total: 48.4ms	remaining: 69.6ms
# 41:	learn: 4651.2406672	total: 49ms	remaining: 67.7ms
# 42:	learn: 4628.0741858	total: 49.6ms	remaining: 65.8ms
# 43:	learn: 4601.6035232	total: 50.2ms	remaining: 63.9ms
# 44:	learn: 4583.4293120	total: 50.8ms	remaining: 62.1ms
# 45:	learn: 4564.8720793	total: 51.5ms	remaining: 60.4ms
# 46:	learn: 4541.4216721	total: 52.1ms	remaining: 58.8ms
# 47:	learn: 4535.4404008	total: 52.5ms	remaining: 56.8ms
# 48:	learn: 4519.9752654	total: 53.1ms	remaining: 55.3ms
# 49:	learn: 4506.1967861	total: 53.7ms	remaining: 53.7ms
# 50:	learn: 4496.1288998	total: 54.3ms	remaining: 52.1ms
# 51:	learn: 4480.4823734	total: 54.8ms	remaining: 50.6ms
# 52:	learn: 4468.6816202	total: 55.4ms	remaining: 49.1ms
# 53:	learn: 4459.1595103	total: 56ms	remaining: 47.7ms
# 54:	learn: 4448.5168936	total: 56.6ms	remaining: 46.3ms
# 55:	learn: 4440.0937763	total: 57.1ms	remaining: 44.9ms
# 56:	learn: 4428.1870313	total: 57.7ms	remaining: 43.5ms
# 57:	learn: 4423.2530009	total: 58ms	remaining: 42ms
# 58:	learn: 4409.7571587	total: 58.6ms	remaining: 40.7ms
# 59:	learn: 4393.7349826	total: 59.3ms	remaining: 39.5ms
# 60:	learn: 4383.3864659	total: 59.8ms	remaining: 38.2ms
# 61:	learn: 4375.0246664	total: 60.4ms	remaining: 37ms
# 62:	learn: 4365.2227756	total: 60.9ms	remaining: 35.8ms
# 63:	learn: 4357.9237305	total: 61.4ms	remaining: 34.5ms
# 64:	learn: 4352.1550570	total: 62ms	remaining: 33.4ms
# 65:	learn: 4343.5118990	total: 62.6ms	remaining: 32.2ms
# 66:	learn: 4336.4107116	total: 63.2ms	remaining: 31.1ms
# 67:	learn: 4330.5812820	total: 63.7ms	remaining: 30ms
# 68:	learn: 4322.8939734	total: 64.4ms	remaining: 28.9ms
# 69:	learn: 4317.4970207	total: 65ms	remaining: 27.9ms
# 70:	learn: 4307.1556212	total: 65.6ms	remaining: 26.8ms
# 71:	learn: 4303.4788902	total: 66.1ms	remaining: 25.7ms
# 72:	learn: 4298.9551086	total: 66.7ms	remaining: 24.7ms
# 73:	learn: 4292.9486051	total: 67.2ms	remaining: 23.6ms
# 74:	learn: 4285.8129173	total: 67.8ms	remaining: 22.6ms
# 75:	learn: 4280.0683466	total: 68.3ms	remaining: 21.6ms
# 76:	learn: 4274.2877356	total: 68.9ms	remaining: 20.6ms
# 77:	learn: 4270.3244523	total: 69.5ms	remaining: 19.6ms
# 78:	learn: 4265.5635257	total: 70.1ms	remaining: 18.6ms
# 79:	learn: 4261.7536448	total: 70.7ms	remaining: 17.7ms
# 80:	learn: 4256.1181039	total: 71.7ms	remaining: 16.8ms
# 81:	learn: 4250.8800022	total: 72.3ms	remaining: 15.9ms
# 82:	learn: 4242.3440996	total: 72.9ms	remaining: 14.9ms
# 83:	learn: 4236.0285122	total: 73.5ms	remaining: 14ms
# 84:	learn: 4232.0728387	total: 74ms	remaining: 13.1ms
# 85:	learn: 4229.1760295	total: 74.5ms	remaining: 12.1ms
# 86:	learn: 4225.4223176	total: 75.1ms	remaining: 11.2ms
# 87:	learn: 4222.9642669	total: 75.7ms	remaining: 10.3ms
# 88:	learn: 4220.6353319	total: 76.5ms	remaining: 9.45ms
# 89:	learn: 4217.6478877	total: 77.1ms	remaining: 8.56ms
# 90:	learn: 4215.3161829	total: 77.7ms	remaining: 7.69ms
# 91:	learn: 4210.5128819	total: 78.3ms	remaining: 6.81ms
# 92:	learn: 4208.2657624	total: 78.9ms	remaining: 5.93ms
# 93:	learn: 4201.8512060	total: 79.4ms	remaining: 5.07ms
# 94:	learn: 4194.2677779	total: 80ms	remaining: 4.21ms
# 95:	learn: 4190.1976925	total: 80.5ms	remaining: 3.35ms
# 96:	learn: 4180.6218633	total: 81.1ms	remaining: 2.51ms
# 97:	learn: 4176.7658434	total: 81.6ms	remaining: 1.67ms
# 98:	learn: 4172.5828625	total: 82.3ms	remaining: 831us
# 99:	learn: 4170.6806005	total: 82.9ms	remaining: 0us
# <catboost.core.CatBoostRegressor object at 0x7c42287eedd0>
# {'n_estimators': 100, 'max_depth': 5, 'learning_rate': 0.06}
#
#
# Train Set Metrics:
# ----------------------------------------------
# MSE is 17394576.548779268
# RMSE is 4170.680585801228
# MAE is 2337.157697153524
# R2 score is 0.885129512408765
# Adjusted R2 score is 0.8839626564400053
#
#
# Test Set Metrics
# ----------------------------------------------
# MSE is 19259995.12642083
# RMSE is 4388.621096246614
# MAE is 2526.8165312297215
# R2 score is 0.8589561532605398
# Adjusted R2 score is 0.856017739786801
#
#
# The top 5 rows of actual vs predicted values
#        Actual Value  Predicted Value
# 559      1646.4297      3015.043914
# 1087    11353.2276     12896.745030
# 1020     8798.5930     10840.537686
# 460     10381.4787     11728.028039
# 802      2103.0800      3373.781077
#             Feature  Feature Importance
# 4            smoker               76.53
# 2               bmi               11.70
# 0               age                9.19
# 3          children                1.40
# 1               sex                0.36
# 6  region_northwest                0.26
# 5  region_northeast                0.25
# 7  region_southeast                0.19
# 8  region_southwest                0.13

# %%
# Save the r2_score
r2_cb = cb[2]
print(r2_cb)
# Out:
# 0.8589561532605398

# %% [markdown]
# ## **Results:**

# %% [markdown]
# ### **Comparison of all the models:**

# %%
# a dataframe to compare all the models
models_df = pd.DataFrame(
    {'Models': ['Linear Regression','Decision Tree', 'Random Forest','XG Boost','Cat Boost'],
     'R2_Score': [r2_lr, r2_dt, r2_rf, r2_xgb, r2_cb]}
)
models_df.sort_values(by=['R2_Score'], ascending=False, inplace=True)
models_df
# Out:
#               Models  R2_Score
# 4          Cat Boost  0.858956
# 2      Random Forest  0.855319
# 3           XG Boost  0.846758
# 1      Decision Tree  0.845139
# 0  Linear Regression  0.739405

# %%
# plot the r2_scpre of all the models
plt.figure(figsize=(13,7))
ax = plt.gca()
models_df.plot(kind='line', x='Models', y='R2_Score', color='blue', ax=ax)
plt.title('R2 Score for all the Models')
plt.xlabel('Model Name')
plt.ylabel('R2 Score')
plt.show()
